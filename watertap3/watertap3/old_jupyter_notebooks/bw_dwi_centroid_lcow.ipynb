# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import haversine as hs
import geopandas as gp
from shapely.geometry import MultiPoint, Point, Polygon
import numpy as np
from sklearn.cluster import KMeans

from pyomo.environ import Var, Expression, NonNegativeReals, Block, ConcreteModel, Constraint, Objective, Param, maximize, SolverFactory,RangeSet
import pyomo.environ as pyo
from idaes.core import FlowsheetBlock
from pyomo.environ import Block, Expression, units as pyunits
import math
from watertap3.utils.watertap_df import watertap_setup,run_watertap3, run_and_return_model, print_results
# from watertap3.utils import watertap_setup,run_watertap3, run_and_return_model
from watertap3.utils import get_case_study

from watertap3.truck_pipe_cost_functions import pipe_costing,elevation_gain, elevation
from pyomo.util.infeasible import log_infeasible_constraints, log_infeasible_bounds

from IPython.display import clear_output

# %%
bw_df = pd.read_csv('/Users/mhardika/Documents/AMO/GeoToolAll_Methods/Water Source Data/Brackish/brackish_sites_with_metrics_baseline_dwi_updated_costs_transport_updated_basis_1.csv')

# %%
contiguous_usa = ('AL','AZ','AR','CA','CO','CT','DE','FL','GA','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE',
                  'NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY','DC')

# %% [markdown]
# Clustering brackish water wells

# %%
bw_df_centroid = pd.read_csv(r'\Users\mhardika\Documents\AMO\GeoToolAll_Methods\Water Source Data\Brackish\wi_bw_lcow_kmeans_2Nov23.csv').drop(['Unnamed: 0'],axis=1)
state_alpha ='TX'

# %%
# Sort in decreasing order of well yield and increasing order of distance
bw_df_centroid_1 = bw_df_centroid.sort_values(['well_yield'],ascending = False, ignore_index=True).sort_values(['dist_miles'],ignore_index=True).groupby('cluster_label')
bw_df_centroid_1 = bw_df_centroid_1.apply(pd.DataFrame)

# bw_df_centroid_1 = bw_df_centroid_1.sort_values(['dist_miles'],ignore_index=True).groupby('cluster_id')
# bw_df_centroid_1 = bw_df_centroid_1.apply(pd.DataFrame)

# %%
bw_df_centroid_1.head(2)
# Out:
#          unique_site_ID state_alpha  county_nm   Latitude  Longitude  \
# 0  USGS-430300087581901          WI  Milwaukee  43.050015 -87.972031
# 1  USGS-430255088001801          WI  Milwaukee  43.048622 -88.005089
#
#    well_depth_ft  well_yield  TDS_kgm3      state  elec_price  ...  elec_int  \
# 0         1837.0    0.048579     0.770  Wisconsin      0.0731  ...  3.884727
# 1         1692.0    0.025236     0.742  Wisconsin      0.0731  ...  3.738203
#
#     tds_out  well_field_o&m  well_field_cap_inv  cluster_label  centroid_long  \
# 0  0.056248        0.218676            0.593448              0     -87.986288
# 1  0.059828        0.105175            0.324953              0     -87.986288
#
#    centroid_lat  dist_miles  centroid_elev   well_elev
# 0     43.074277    2.936008     228.538528  216.597595
# 1     43.074277    3.235908     228.538528  199.142075
#
# [2 rows x 25 columns]

# %% [markdown]
# Function to create treatment train CSV s

# %%
# bw_df_centroid_1[bw_df_centroid_1['cluster_label']==1]

# %%
cols = ['state','state_elec_price','cluster_id','centroid_long','centroid_lat','centroid_elev','well_count','well_id','well_elev',
                        'latitude','longitude','well_depth','well_yield','elect_int_old','tds','dist','avg_well_yield','avg_tds']
bw_cluster_lcow = pd.DataFrame(columns=cols)

bw_df_centroid_sample = bw_df_centroid_1[bw_df_centroid_1['state_alpha'] == state_alpha]

# Iterate through each cluster id
for cl_id in bw_df_centroid_sample.cluster_label.unique():
        bw_cluster = bw_df_centroid_sample[bw_df_centroid_sample['cluster_label']==cl_id]
        # TDS 
        avg_tds = 0
        # well yield
        avg_well_yield  = 0
        well_list = []
        lat_list = []
        long_list = []
        well_depth_list = []
        well_yield_list = []
        tds_list = []
        dist_list = []
        # This is  electrical intensity in Kwh/m3
        elect_list = []

        centroid_elev_list = []
        well_elev_list = []

        well_count = 0
        # Iterate over each brackish water site within a cluster
        for well_id in bw_cluster['unique_site_ID'].unique():

                well_count = well_count + 1
                bw_cluster_well = bw_cluster[bw_cluster['unique_site_ID']==well_id]
                # Calculate average well yield
                avg_well_yield_old = avg_well_yield
                avg_well_yield = avg_well_yield + bw_cluster[bw_cluster['unique_site_ID']==well_id]['well_yield'].values[0]

                # Calculate average TDS
                avg_tds = (avg_tds*avg_well_yield_old + bw_cluster[bw_cluster['unique_site_ID']==well_id]['TDS_kgm3'].values[0] * bw_cluster[bw_cluster['unique_site_ID']==well_id]['well_yield'].values[0])/avg_well_yield
                
                well_list.append(well_id)
                lat_list.append(bw_cluster_well['Latitude'].values)
                long_list.append(bw_cluster_well['Longitude'].values)
                well_depth_list.append(bw_cluster_well['well_depth_ft'].values)
                well_yield_list.append(bw_cluster_well['well_yield'].values)
                tds_list.append(bw_cluster_well['TDS_kgm3'].values)
                dist_list.append(bw_cluster_well['dist_miles'].values)
                # centroid_elev_list.append(bw_cluster_well['centroid_elev'])
                elect_list.append(bw_cluster_well['elec_int'].values)
                well_elev_list.append(bw_cluster_well['well_elev'])

                
                # Update results table
                temp = {'state': state_alpha,
                        'state_elec_price': bw_df_centroid_sample['elec_price'].unique()[0],
                        'cluster_id': cl_id,
                        'centroid_long':bw_cluster['centroid_long'].unique()[0],
                        'centroid_lat':bw_cluster['centroid_lat'].unique()[0],
                        # 'centroid_elev': list(centroid_elev_list),
                        'centroid_elev': bw_cluster_well['centroid_elev'].unique()[0],
                        'well_count': well_count,
                        'well_id': list(well_list),
                        'well_elev': list(well_elev_list),
                        'latitude': list(lat_list),
                        'longitude': list(long_list),
                        'well_depth': list(well_depth_list),
                        'well_yield':list(well_yield_list),
                        'elect_int_old':list(elect_list),
                        'tds': list(tds_list),
                        'dist':list(dist_list),
                        'avg_well_yield': avg_well_yield,
                        'avg_tds':avg_tds
                        }
                
                temp = pd.DataFrame([temp])
                bw_cluster_lcow = pd.concat([bw_cluster_lcow,temp],ignore_index=True)
                # bw_cluster_lcow.reset_index()

bw_cluster_lcow.head(2)
# Out:
#   state  state_elec_price cluster_id  centroid_long  centroid_lat  \
# 0    CA             0.134          5    -120.121315     40.145180
# 1    CA             0.134          8    -122.434575     38.247101
#
#    centroid_elev well_count                 well_id           well_elev  \
# 0    1251.174927          1  [USGS-400843120071301]  [[1251.174926758]]
# 1       3.479558          1  [USGS-381443122254201]     [[4.335468292]]
#
#          latitude         longitude well_depth      well_yield  \
# 0  [[40.1451797]]   [[-120.121315]]  [[692.0]]  [[0.13248942]]
# 1   [[38.245472]]  [[-122.4283371]]  [[821.0]]   [[0.0630902]]
#
#             elect_int_old            tds                    dist  \
# 0  [[2.3991396084885084]]       [[0.82]]                 [[0.0]]
# 1  [[2.6127207018375214]]  [[1.0231004]]  [[0.5740958930743217]]
#
#    avg_well_yield  avg_tds
# 0        0.132489   0.8200
# 1        0.063090   1.0231

# %% [markdown]
# Preliminary steps to calculate treatment portion of LCOW

# %%
# Get relevant case study
case_study = 'big_spring'
scenario = 'dwi_a'
reference='nawi'

df1 = pd.read_csv('/Users/mhardika/Documents/watertap3/WaterTAP3/watertap3/watertap3/data/treatment_train_setup.csv')
df = df1[((df1.Reference == reference) & (df1.Scenario == scenario) & (df1.CaseStudy == case_study))].tail(6).copy()

desired_recovery = 1
ro_bounds = 'other'

# %% [markdown]
# Functions for calculating LCOW

# %%
def create_treatment_train(row,df):
    # well_depth = list(bw_cluster_lcow['well_depth'])
    # df_well  = pd.DataFrame(columns= df.columns)
    # print(df_well['Parameter'].get('water_type'))

    # for index,row in bw_cluster_lcow.iterrows():
    df_well  = pd.DataFrame(columns= df.columns)
    for i in range(0,len(row['well_depth'])):

        if i == 0:
                type_var = 'intake'
        else:
                type_var = 'treatment'

        if (i == len(row['well_depth']) -1 ):
                toUnit_var = 'microfiltration'
        else:
                toUnit_var = 'well_field_'+str(i+1)

        temp = {'CaseStudy':'big_spring',
                'Reference':'nawi',
                'Scenario':'dwi_a',
                'Unit':'well_field',
                'Type':type_var,
                'UnitName':'well_field_'+str(i),
                'ToUnitName': toUnit_var,
                'FromPort':'outlet',
                'Parameter':str({'water_type': ['big_spring_feed'],'lift_height': row['well_depth'][i][0],'flow_in': row['well_yield'][i][0]*3600}),
            }

        temp = pd.DataFrame([temp])
        df_well = pd.concat([df_well,temp])

    df_centroid = pd.concat([df_well,df])

    return df_centroid

def solve_treatment_train(df_centroid,avg_well_yield,avg_tds,elec_price):
    # print(avg_well_yield)
    
    m = watertap_setup(case_study=case_study, scenario=scenario, treatment_df=df_centroid)
    m = get_case_study(m=m)
    try:
        m = run_watertap3(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds, treatment_df=df_centroid)
          
        m.fs.reverse_osmosis.membrane_area.unfix()
        m.fs.reverse_osmosis.feed.pressure.unfix()

        # Updating parameters
        m.fs.big_spring_feed.flow_vol_in.fix(avg_well_yield)
        m.fs.big_spring_feed.conc_mass_in[0, 'tds'].fix(avg_tds)
        m.fs.costing_param.electricity_price = elec_price

        m = run_and_return_model(m, objective=True,print_it=True)

    except:
        # print(log_infeasible_constraints(m))
        pass
    
    return m

i = 2
print(bw_cluster_lcow.iloc[i].avg_well_yield)
df_centroid = create_treatment_train(bw_cluster_lcow.iloc[i],df)
m = solve_treatment_train(df_centroid,bw_cluster_lcow.iloc[i].avg_well_yield,bw_cluster_lcow.iloc[i].avg_tds,0.134)
# df_centroid.head()
# Out:
# 0.0757082399999999
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.07035
# Total Capital Investment ($MM): 16.936
# Total Annual Operating Costs ($MM/yr): 1.24
# Annual Fixed Operating Cost ($MM/yr): 0.225
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.046
# Annual Electricity Costs ($MM/yr): 0.896
# Annual Other Variable Costs ($MM/yr): 0.072
# Treated water (m3/s): 0.069
# Total water recovery (%): 91.636
# Electricity intensity (kWh/m3): 3.056
# Electricity portion of LCOW (%): 38.262
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 0.75469
# 	Annual O&M ($MM/yr): 0.27916
# 	Annual Fixed O&M ($MM/yr): 0.01001
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.26915
# 	Electricity Intensity (kWh/m3): 0.84069
# 	Unit LCOW ($/m3): 0.15003
# 	Flow In (m3/s): 0.07571
# 	Flow Out (m3/s): 0.0757
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Well Field 1:
# 	Total Capital Investment ($MM): 0.17179
# 	Annual O&M ($MM/yr): 0.13799
# 	Annual Fixed O&M ($MM/yr): 0.00228
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.13571
# 	Electricity Intensity (kWh/m3): 0.42393
# 	Unit LCOW ($/m3): 0.06818
# 	Flow In (m3/s): 0.0757
# 	Flow Out (m3/s): 0.07569
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 4.92938
# 	Annual O&M ($MM/yr): 0.12325
# 	Annual Fixed O&M ($MM/yr): 0.06564
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.05762
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.2029
# 	Flow In (m3/s): 0.07569
# 	Flow Out (m3/s): 0.07191
# 	Flow Waste (m3/s): 0.00378
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 2.94595
# 	Annual O&M ($MM/yr): 0.44241
# 	Annual Fixed O&M ($MM/yr): 0.03923
# 	Annual Chemical Cost ($MM/yr): 0.02802
# 	Annual Electricity Cost ($MM/yr): 0.30281
# 	Electricity Intensity (kWh/m3): 0.99581
# 	Unit LCOW ($/m3): 0.28981
# 	Flow In (m3/s): 0.07191
# 	Flow Out (m3/s): 0.0694
# 	Flow Waste (m3/s): 0.00271
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 29.68 bar = 430 psi
# 	Area = 9648 m2 ---> 260 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 992.277 mg/L
# 	TDS out = 62.577 mg/L
# 	TDS waste = 24727.669 mg/L
# 	Flow in = 0.07191 m3/s = 1.64127 MGD = 1139.77 gpm
# 	Flow out = 0.0694 m3/s = 1.58395 MGD = 1099.96 gpm
# 	Flow waste = 0.00271 m3/s = 0.06185 MGD = 42.95 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 96.5%
#
# UV AOP:
# 	Total Capital Investment ($MM): 4.49526
# 	Annual O&M ($MM/yr): 0.10756
# 	Annual Fixed O&M ($MM/yr): 0.05986
# 	Annual Chemical Cost ($MM/yr): 0.01836
# 	Annual Electricity Cost ($MM/yr): 0.02935
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.18282
# 	Flow In (m3/s): 0.0694
# 	Flow Out (m3/s): 0.06939
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 1.1135
# 	Annual O&M ($MM/yr): 0.01464
# 	Annual Fixed O&M ($MM/yr): 0.01464
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0398
# 	Flow In (m3/s): 0.06939
# 	Flow Out (m3/s): 0.06938
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.2145
# 	Annual O&M ($MM/yr): 0.09298
# 	Annual Fixed O&M ($MM/yr): 0.00285
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.09013
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04888
# 	Flow In (m3/s): 0.06938
# 	Flow Out (m3/s): 0.06938
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 2.31085
# 	Annual O&M ($MM/yr): 0.04206
# 	Annual Fixed O&M ($MM/yr): 0.03081
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.01125
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.08793
# 	Flow In (m3/s): 0.00649
# 	Flow Out (m3/s): 0.00649
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================

# %%
# Get individual well data
# bw_cluster_lcow.iloc[i]

def calc_well_lcow(well_depth, flow_in, conc, elec_price):
    case_study = 'big_spring'
    scenario = 'dwi_a'
    desired_recovery = 1
    ro_bounds = 'other' # or 'seawater'

    m = watertap_setup(case_study=case_study, scenario=scenario)
    m = get_case_study(m=m)

    # run the baseline watertap3 version of this treatment train
    m = run_watertap3(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds)

    m.fs.reverse_osmosis.membrane_area.unfix()
    m.fs.reverse_osmosis.feed.pressure.unfix()  

    m.fs.big_spring_feed.flow_vol_in.fix(flow_in)
    m.fs.big_spring_feed.conc_mass_in[0, 'tds'].fix(conc)
    m.fs.well_field.lift_height.fix(well_depth)
    m.fs.costing_param.electricity_price = elec_price

    m = run_and_return_model(m, objective=True,print_it=True)

    return m

n = len(bw_cluster_lcow.iloc[i].well_yield)

for k in range(0,n):
    # print(bw_cluster_lcow.iloc[i].well_yield[k][0])
    print(bw_cluster_lcow.iloc[i].well_id[k])
    well_depth = bw_cluster_lcow.iloc[i].well_depth[k][0]
    flow_in = bw_cluster_lcow.iloc[i].well_yield[k][0]
    conc = bw_cluster_lcow.iloc[i].tds[k][0]
    elec_price = 0.134

    m = calc_well_lcow(well_depth, flow_in, conc, elec_price)
# Out:
# USGS-381443122254201
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.04111
# Total Capital Investment ($MM): 14.786
# Total Annual Operating Costs ($MM/yr): 0.933
# Annual Fixed Operating Cost ($MM/yr): 0.197
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.039
# Annual Electricity Costs ($MM/yr): 0.637
# Annual Other Variable Costs ($MM/yr): 0.06
# Treated water (m3/s): 0.058
# Total water recovery (%): 91.475
# Electricity intensity (kWh/m3): 2.613
# Electricity portion of LCOW (%): 33.628
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field:
# 	Total Capital Investment ($MM): 0.75469
# 	Annual O&M ($MM/yr): 0.2343
# 	Annual Fixed O&M ($MM/yr): 0.01001
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.22429
# 	Electricity Intensity (kWh/m3): 0.84069
# 	Unit LCOW ($/m3): 0.15571
# 	Flow In (m3/s): 0.06309
# 	Flow Out (m3/s): 0.06308
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 4.10823
# 	Annual O&M ($MM/yr): 0.10272
# 	Annual Fixed O&M ($MM/yr): 0.0547
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.04802
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20328
# 	Flow In (m3/s): 0.06308
# 	Flow Out (m3/s): 0.05993
# 	Flow Waste (m3/s): 0.00315
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 2.47214
# 	Annual O&M ($MM/yr): 0.37261
# 	Annual Fixed O&M ($MM/yr): 0.03292
# 	Annual Chemical Cost ($MM/yr): 0.02351
# 	Annual Electricity Cost ($MM/yr): 0.25593
# 	Electricity Intensity (kWh/m3): 1.00988
# 	Unit LCOW ($/m3): 0.29309
# 	Flow In (m3/s): 0.05993
# 	Flow Out (m3/s): 0.05773
# 	Flow Waste (m3/s): 0.00237
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 30.08 bar = 436 psi
# 	Area = 8033 m2 ---> 216 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 1077.034 mg/L
# 	TDS out = 65.188 mg/L
# 	TDS waste = 25692.227 mg/L
# 	Flow in = 0.05993 m3/s = 1.36786 MGD = 949.91 gpm
# 	Flow out = 0.05773 m3/s = 1.31763 MGD = 915.02 gpm
# 	Flow waste = 0.00237 m3/s = 0.054 MGD = 37.5 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 96.3%
#
# UV AOP:
# 	Total Capital Investment ($MM): 4.23114
# 	Annual O&M ($MM/yr): 0.09602
# 	Annual Fixed O&M ($MM/yr): 0.05634
# 	Annual Chemical Cost ($MM/yr): 0.01527
# 	Annual Electricity Cost ($MM/yr): 0.02441
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.20399
# 	Flow In (m3/s): 0.05773
# 	Flow Out (m3/s): 0.05772
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 0.97511
# 	Annual O&M ($MM/yr): 0.01282
# 	Annual Fixed O&M ($MM/yr): 0.01282
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0419
# 	Flow In (m3/s): 0.05772
# 	Flow Out (m3/s): 0.05772
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.1829
# 	Annual O&M ($MM/yr): 0.0774
# 	Annual Fixed O&M ($MM/yr): 0.00243
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.07498
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04907
# 	Flow In (m3/s): 0.05772
# 	Flow Out (m3/s): 0.05771
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 2.06226
# 	Annual O&M ($MM/yr): 0.03705
# 	Annual Fixed O&M ($MM/yr): 0.02749
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00956
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.09407
# 	Flow In (m3/s): 0.00552
# 	Flow Out (m3/s): 0.00552
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
# USGS-381540122254701
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.41026
# Total Capital Investment ($MM): 5.095
# Total Annual Operating Costs ($MM/yr): 0.191
# Annual Fixed Operating Cost ($MM/yr): 0.068
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.008
# Annual Electricity Costs ($MM/yr): 0.103
# Annual Other Variable Costs ($MM/yr): 0.012
# Treated water (m3/s): 0.012
# Total water recovery (%): 93.1
# Electricity intensity (kWh/m3): 2.072
# Electricity portion of LCOW (%): 19.687
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field:
# 	Total Capital Investment ($MM): 0.17179
# 	Annual O&M ($MM/yr): 0.0249
# 	Annual Fixed O&M ($MM/yr): 0.00228
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.02262
# 	Electricity Intensity (kWh/m3): 0.42393
# 	Unit LCOW ($/m3): 0.09738
# 	Flow In (m3/s): 0.01262
# 	Flow Out (m3/s): 0.01262
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 0.82165
# 	Annual O&M ($MM/yr): 0.02054
# 	Annual Fixed O&M ($MM/yr): 0.01094
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0096
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.19973
# 	Flow In (m3/s): 0.01262
# 	Flow Out (m3/s): 0.01199
# 	Flow Waste (m3/s): 0.00063
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 0.5246
# 	Annual O&M ($MM/yr): 0.07307
# 	Annual Fixed O&M ($MM/yr): 0.00699
# 	Annual Chemical Cost ($MM/yr): 0.00499
# 	Annual Electricity Cost ($MM/yr): 0.04884
# 	Electricity Intensity (kWh/m3): 0.96361
# 	Unit LCOW ($/m3): 0.28937
# 	Flow In (m3/s): 0.01199
# 	Flow Out (m3/s): 0.01175
# 	Flow Waste (m3/s): 0.00027
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 28.75 bar = 417 psi
# 	Area = 1634 m2 ---> 44 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 567.956 mg/L
# 	TDS out = 56.991 mg/L
# 	TDS waste = 22845.295 mg/L
# 	Flow in = 0.01199 m3/s = 0.27357 MGD = 189.98 gpm
# 	Flow out = 0.01175 m3/s = 0.26821 MGD = 186.26 gpm
# 	Flow waste = 0.00027 m3/s = 0.00613 MGD = 4.26 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 98.0%
#
# UV AOP:
# 	Total Capital Investment ($MM): 2.64242
# 	Annual O&M ($MM/yr): 0.04326
# 	Annual Fixed O&M ($MM/yr): 0.03519
# 	Annual Chemical Cost ($MM/yr): 0.00311
# 	Annual Electricity Cost ($MM/yr): 0.00497
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.58077
# 	Flow In (m3/s): 0.01175
# 	Flow Out (m3/s): 0.01175
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 0.3095
# 	Annual O&M ($MM/yr): 0.00407
# 	Annual Fixed O&M ($MM/yr): 0.00407
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.06533
# 	Flow In (m3/s): 0.01175
# 	Flow Out (m3/s): 0.01175
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.0461
# 	Annual O&M ($MM/yr): 0.01587
# 	Annual Fixed O&M ($MM/yr): 0.00061
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.01526
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.05094
# 	Flow In (m3/s): 0.01175
# 	Flow Out (m3/s): 0.01175
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 0.57915
# 	Annual O&M ($MM/yr): 0.00928
# 	Annual Fixed O&M ($MM/yr): 0.00772
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00156
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.12674
# 	Flow In (m3/s): 0.0009
# 	Flow Out (m3/s): 0.0009
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================

# %%
m.fs.well_field.lift_height.display()
# Out:
# lift_height : Lift height for well pump [ft]
#     Size=1, Index=fs.time
#     Key : Lower : Value : Upper    : Fixed : Stale : Domain
#     0.0 :     0 : 800.0 : 100000.0 :  True :  True : NonNegativeReals

# %%
print(well_depth)
# Out:
# 800.0

# %%
def bw_transport(row):

    bw_transport_lcow = 0
    for i in range(0,len(row['well_depth'])):
        # Calculate elevation gain
        centroid_lon = row['centroid_long']
        centroid_lat = row['centroid_lat']

        well_lon = row['longitude'][i][0]
        well_lat = row['latitude'][i][0]

        # elev_gain = elevation_gain(centroid_lat,centroid_lon,well_lat,well_lon)
        elev_gain = row['centroid_elev']- row['well_elev'][i].values[0]
        # print(elev_gain)

        if elev_gain <= 0:
            elev_gain = 1e-5
        
        # Calculate pipe lcow for each well

        dist = row['dist'][i][0]*1.6 # Converting distance from miles to km
        capacity  = row['well_yield'][i][0]*3600*24  #m3/s -> m3/day

        elec_price = row['state_elec_price']
        
        # pipe_LCOW * Volume = $
        pipe_lcow = pipe_costing(capacity, dist, elev_gain = elev_gain, electricity_rate = elec_price)*capacity
        
        bw_transport_lcow = bw_transport_lcow + pipe_lcow    

    return bw_transport_lcow

# bw_transport(bw_cluster_lcow.iloc[39])

# %% [markdown]
# Function to
# 1. Calculate well pumping cost
# 2. Transport cost to treatment facility
# 3. Brine transport cost
# 4. Total LCOW

# %%
def calc_lcow(row, df):
# Extracting variables for functions
    # well_depth = row['well_depth']
    # tds = row['tds']
    # well_yield = row['well_yield']

    avg_well_yield = row['avg_well_yield']
    avg_tds = row['avg_tds']
    elec_price = row['state_elec_price']

    # Create treatment train
    df_centroid = create_treatment_train(row,df)  
     
    # Calculate treatment lcow 
    try:
        m = solve_treatment_train(df_centroid,avg_well_yield,avg_tds,elec_price)
        treatment_lcow = m.fs.costing.LCOW()

        # Calculate brackish transport cost from well to treatment site
        bw_transport_lcow = bw_transport(row)/(avg_well_yield*3600*24*m.fs.costing.system_recovery())

        # Calculate brine transport cost
        brine_flow = m.fs.deep_well_injection.flow_vol_in[0].value*3600*24
        dist_to_dwi = 10 #km
        brine_transport_lcow = pipe_costing(brine_flow, dist_to_dwi, elev_gain = 1e-5, electricity_rate = elec_price)*(1-m.fs.costing.system_recovery())/m.fs.costing.system_recovery()
        
        if m.fs.results.solver.termination_condition in ['infeasible', 'maxIterations', 'unbounded', 'other']:
            treatment_lcow = 0
            bw_transport_lcow = 0
            brine_transport_lcow = 0
            
    except ValueError:
        treatment_lcow = 0
        bw_transport_lcow = 0
        brine_transport_lcow = 0
        
    except : 
        treatment_lcow = 0
        bw_transport_lcow = 0
        brine_transport_lcow = 0 
    
    lcow = treatment_lcow + bw_transport_lcow + brine_transport_lcow
    elect_int = m.fs.costing.electricity_intensity()
    recovery = m.fs.costing.system_recovery()*100

    return [treatment_lcow, bw_transport_lcow,brine_transport_lcow, lcow, elect_int]

# calc_lcow(bw_cluster_lcow.iloc[1],df)

# %% [markdown]
# Running the centroid LCOW calculations for Arizona

# %%
lcow_list = []
treatment_lcow_list = []
bw_transport_lcow_list = []
brine_transport_lcow_list = []
elect_int_list = []

for idx,row in bw_cluster_lcow.iterrows():
    treatment_lcow, bw_transport_lcow,brine_transport_lcow, lcow,elect_int = calc_lcow(row,df)
    # lcow,elect_int = calc_lcow(row,df)
    lcow_list.append(lcow)
    treatment_lcow_list.append(treatment_lcow)
    bw_transport_lcow_list.append(bw_transport_lcow)
    brine_transport_lcow_list.append(brine_transport_lcow)
    elect_int_list.append(elect_int)
    # clear_output(wait=True)

# print(elect_int_list)
# Out:
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 0.90893
# Total Capital Investment ($MM): 26.057
# Total Annual Operating Costs ($MM/yr): 1.783
# Annual Fixed Operating Cost ($MM/yr): 0.347
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.08
# Annual Electricity Costs ($MM/yr): 1.23
# Annual Other Variable Costs ($MM/yr): 0.126
# Treated water (m3/s): 0.121
# Total water recovery (%): 91.584
# Electricity intensity (kWh/m3): 2.399
# Electricity portion of LCOW (%): 35.369
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 1.49307
# 	Annual O&M ($MM/yr): 0.41681
# 	Annual Fixed O&M ($MM/yr): 0.01981
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.397
# 	Electricity Intensity (kWh/m3): 0.7086
# 	Unit LCOW ($/m3): 0.13431
# 	Flow In (m3/s): 0.13249
# 	Flow Out (m3/s): 0.13248
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 8.62727
# 	Annual O&M ($MM/yr): 0.21572
# 	Annual Fixed O&M ($MM/yr): 0.11488
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.10084
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20304
# 	Flow In (m3/s): 0.13248
# 	Flow Out (m3/s): 0.12585
# 	Flow Waste (m3/s): 0.00662
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 5.028
# 	Annual O&M ($MM/yr): 0.74455
# 	Annual Fixed O&M ($MM/yr): 0.06695
# 	Annual Chemical Cost ($MM/yr): 0.04782
# 	Annual Electricity Cost ($MM/yr): 0.50354
# 	Electricity Intensity (kWh/m3): 0.94616
# 	Unit LCOW ($/m3): 0.28005
# 	Flow In (m3/s): 0.12585
# 	Flow Out (m3/s): 0.12138
# 	Flow Waste (m3/s): 0.00482
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 28.25 bar = 410 psi
# 	Area = 16832 m2 ---> 453 membrane modules
# 	Flux = 26.0 LMH
# 	TDS in = 863.227 mg/L
# 	TDS out = 53.481 mg/L
# 	TDS waste = 21173.725 mg/L
# 	Flow in = 0.12585 m3/s = 2.87251 MGD = 1994.8 gpm
# 	Flow out = 0.12138 m3/s = 2.77032 MGD = 1923.84 gpm
# 	Flow waste = 0.00482 m3/s = 0.11011 MGD = 76.47 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 96.39999999999999%
#
# UV AOP:
# 	Total Capital Investment ($MM): 5.45853
# 	Annual O&M ($MM/yr): 0.15612
# 	Annual Fixed O&M ($MM/yr): 0.07268
# 	Annual Chemical Cost ($MM/yr): 0.0321
# 	Annual Electricity Cost ($MM/yr): 0.05133
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.13359
# 	Flow In (m3/s): 0.12138
# 	Flow Out (m3/s): 0.12136
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 1.66619
# 	Annual O&M ($MM/yr): 0.0219
# 	Annual Fixed O&M ($MM/yr): 0.0219
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.03405
# 	Flow In (m3/s): 0.12136
# 	Flow Out (m3/s): 0.12135
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.34803
# 	Annual O&M ($MM/yr): 0.16226
# 	Annual Fixed O&M ($MM/yr): 0.00462
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.15764
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04832
# 	Flow In (m3/s): 0.12135
# 	Flow Out (m3/s): 0.12134
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 3.43635
# 	Annual O&M ($MM/yr): 0.06564
# 	Annual Fixed O&M ($MM/yr): 0.04581
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.01983
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.07557
# 	Flow In (m3/s): 0.01145
# 	Flow Out (m3/s): 0.01145
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.04111
# Total Capital Investment ($MM): 14.786
# Total Annual Operating Costs ($MM/yr): 0.933
# Annual Fixed Operating Cost ($MM/yr): 0.197
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.039
# Annual Electricity Costs ($MM/yr): 0.637
# Annual Other Variable Costs ($MM/yr): 0.06
# Treated water (m3/s): 0.058
# Total water recovery (%): 91.475
# Electricity intensity (kWh/m3): 2.613
# Electricity portion of LCOW (%): 33.628
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 0.75469
# 	Annual O&M ($MM/yr): 0.2343
# 	Annual Fixed O&M ($MM/yr): 0.01001
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.22429
# 	Electricity Intensity (kWh/m3): 0.84069
# 	Unit LCOW ($/m3): 0.15571
# 	Flow In (m3/s): 0.06309
# 	Flow Out (m3/s): 0.06308
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 4.10823
# 	Annual O&M ($MM/yr): 0.10272
# 	Annual Fixed O&M ($MM/yr): 0.0547
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.04802
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20328
# 	Flow In (m3/s): 0.06308
# 	Flow Out (m3/s): 0.05993
# 	Flow Waste (m3/s): 0.00315
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 2.47214
# 	Annual O&M ($MM/yr): 0.37261
# 	Annual Fixed O&M ($MM/yr): 0.03292
# 	Annual Chemical Cost ($MM/yr): 0.02351
# 	Annual Electricity Cost ($MM/yr): 0.25593
# 	Electricity Intensity (kWh/m3): 1.00988
# 	Unit LCOW ($/m3): 0.29309
# 	Flow In (m3/s): 0.05993
# 	Flow Out (m3/s): 0.05773
# 	Flow Waste (m3/s): 0.00237
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 30.08 bar = 436 psi
# 	Area = 8033 m2 ---> 216 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 1077.034 mg/L
# 	TDS out = 65.188 mg/L
# 	TDS waste = 25692.227 mg/L
# 	Flow in = 0.05993 m3/s = 1.36786 MGD = 949.91 gpm
# 	Flow out = 0.05773 m3/s = 1.31763 MGD = 915.02 gpm
# 	Flow waste = 0.00237 m3/s = 0.054 MGD = 37.5 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 96.3%
#
# UV AOP:
# 	Total Capital Investment ($MM): 4.23114
# 	Annual O&M ($MM/yr): 0.09602
# 	Annual Fixed O&M ($MM/yr): 0.05634
# 	Annual Chemical Cost ($MM/yr): 0.01527
# 	Annual Electricity Cost ($MM/yr): 0.02441
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.20399
# 	Flow In (m3/s): 0.05773
# 	Flow Out (m3/s): 0.05772
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 0.97511
# 	Annual O&M ($MM/yr): 0.01282
# 	Annual Fixed O&M ($MM/yr): 0.01282
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0419
# 	Flow In (m3/s): 0.05772
# 	Flow Out (m3/s): 0.05772
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.1829
# 	Annual O&M ($MM/yr): 0.0774
# 	Annual Fixed O&M ($MM/yr): 0.00243
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.07498
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04907
# 	Flow In (m3/s): 0.05772
# 	Flow Out (m3/s): 0.05771
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 2.06226
# 	Annual O&M ($MM/yr): 0.03705
# 	Annual Fixed O&M ($MM/yr): 0.02749
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00956
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.09407
# 	Flow In (m3/s): 0.00552
# 	Flow Out (m3/s): 0.00552
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.07035
# Total Capital Investment ($MM): 16.936
# Total Annual Operating Costs ($MM/yr): 1.24
# Annual Fixed Operating Cost ($MM/yr): 0.225
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.046
# Annual Electricity Costs ($MM/yr): 0.896
# Annual Other Variable Costs ($MM/yr): 0.072
# Treated water (m3/s): 0.069
# Total water recovery (%): 91.636
# Electricity intensity (kWh/m3): 3.056
# Electricity portion of LCOW (%): 38.262
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 0.75469
# 	Annual O&M ($MM/yr): 0.27916
# 	Annual Fixed O&M ($MM/yr): 0.01001
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.26915
# 	Electricity Intensity (kWh/m3): 0.84069
# 	Unit LCOW ($/m3): 0.15003
# 	Flow In (m3/s): 0.07571
# 	Flow Out (m3/s): 0.0757
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Well Field 1:
# 	Total Capital Investment ($MM): 0.17179
# 	Annual O&M ($MM/yr): 0.13799
# 	Annual Fixed O&M ($MM/yr): 0.00228
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.13571
# 	Electricity Intensity (kWh/m3): 0.42393
# 	Unit LCOW ($/m3): 0.06818
# 	Flow In (m3/s): 0.0757
# 	Flow Out (m3/s): 0.07569
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 4.92938
# 	Annual O&M ($MM/yr): 0.12325
# 	Annual Fixed O&M ($MM/yr): 0.06564
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.05762
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.2029
# 	Flow In (m3/s): 0.07569
# 	Flow Out (m3/s): 0.07191
# 	Flow Waste (m3/s): 0.00378
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 2.94595
# 	Annual O&M ($MM/yr): 0.44241
# 	Annual Fixed O&M ($MM/yr): 0.03923
# 	Annual Chemical Cost ($MM/yr): 0.02802
# 	Annual Electricity Cost ($MM/yr): 0.30281
# 	Electricity Intensity (kWh/m3): 0.99581
# 	Unit LCOW ($/m3): 0.28981
# 	Flow In (m3/s): 0.07191
# 	Flow Out (m3/s): 0.0694
# 	Flow Waste (m3/s): 0.00271
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 29.68 bar = 430 psi
# 	Area = 9648 m2 ---> 260 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 992.277 mg/L
# 	TDS out = 62.577 mg/L
# 	TDS waste = 24727.669 mg/L
# 	Flow in = 0.07191 m3/s = 1.64127 MGD = 1139.77 gpm
# 	Flow out = 0.0694 m3/s = 1.58395 MGD = 1099.96 gpm
# 	Flow waste = 0.00271 m3/s = 0.06185 MGD = 42.95 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 96.5%
#
# UV AOP:
# 	Total Capital Investment ($MM): 4.49526
# 	Annual O&M ($MM/yr): 0.10756
# 	Annual Fixed O&M ($MM/yr): 0.05986
# 	Annual Chemical Cost ($MM/yr): 0.01836
# 	Annual Electricity Cost ($MM/yr): 0.02935
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.18282
# 	Flow In (m3/s): 0.0694
# 	Flow Out (m3/s): 0.06939
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 1.1135
# 	Annual O&M ($MM/yr): 0.01464
# 	Annual Fixed O&M ($MM/yr): 0.01464
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0398
# 	Flow In (m3/s): 0.06939
# 	Flow Out (m3/s): 0.06938
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.2145
# 	Annual O&M ($MM/yr): 0.09298
# 	Annual Fixed O&M ($MM/yr): 0.00285
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.09013
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04888
# 	Flow In (m3/s): 0.06938
# 	Flow Out (m3/s): 0.06938
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 2.31085
# 	Annual O&M ($MM/yr): 0.04206
# 	Annual Fixed O&M ($MM/yr): 0.03081
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.01125
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.08793
# 	Flow In (m3/s): 0.00649
# 	Flow Out (m3/s): 0.00649
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.129
# Total Capital Investment ($MM): 23.128
# Total Annual Operating Costs ($MM/yr): 2.212
# Annual Fixed Operating Cost ($MM/yr): 0.308
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.069
# Annual Electricity Costs ($MM/yr): 1.726
# Annual Other Variable Costs ($MM/yr): 0.109
# Treated water (m3/s): 0.104
# Total water recovery (%): 91.912
# Electricity intensity (kWh/m3): 3.914
# Electricity portion of LCOW (%): 46.45
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 0.75469
# 	Annual O&M ($MM/yr): 0.41373
# 	Annual Fixed O&M ($MM/yr): 0.01001
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.40372
# 	Electricity Intensity (kWh/m3): 0.84069
# 	Unit LCOW ($/m3): 0.14061
# 	Flow In (m3/s): 0.11356
# 	Flow Out (m3/s): 0.11355
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Well Field 1:
# 	Total Capital Investment ($MM): 0.17179
# 	Annual O&M ($MM/yr): 0.20584
# 	Annual Fixed O&M ($MM/yr): 0.00228
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.20356
# 	Electricity Intensity (kWh/m3): 0.42393
# 	Unit LCOW ($/m3): 0.06593
# 	Flow In (m3/s): 0.11355
# 	Flow Out (m3/s): 0.11354
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Well Field 2:
# 	Total Capital Investment ($MM): 0.4718
# 	Annual O&M ($MM/yr): 0.39957
# 	Annual Fixed O&M ($MM/yr): 0.00626
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.39332
# 	Electricity Intensity (kWh/m3): 0.81919
# 	Unit LCOW ($/m3): 0.13071
# 	Flow In (m3/s): 0.11354
# 	Flow Out (m3/s): 0.11353
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 7.39333
# 	Annual O&M ($MM/yr): 0.18486
# 	Annual Fixed O&M ($MM/yr): 0.09845
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.08641
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20227
# 	Flow In (m3/s): 0.11353
# 	Flow Out (m3/s): 0.10785
# 	Flow Waste (m3/s): 0.00568
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 4.36649
# 	Annual O&M ($MM/yr): 0.65151
# 	Annual Fixed O&M ($MM/yr): 0.05814
# 	Annual Chemical Cost ($MM/yr): 0.04153
# 	Annual Electricity Cost ($MM/yr): 0.44313
# 	Electricity Intensity (kWh/m3): 0.97162
# 	Unit LCOW ($/m3): 0.28422
# 	Flow In (m3/s): 0.10785
# 	Flow Out (m3/s): 0.10441
# 	Flow Waste (m3/s): 0.00374
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 28.98 bar = 420 psi
# 	Area = 14494 m2 ---> 390 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 856.249 mg/L
# 	TDS out = 58.094 mg/L
# 	TDS waste = 23057.185 mg/L
# 	Flow in = 0.10785 m3/s = 2.46166 MGD = 1709.49 gpm
# 	Flow out = 0.10441 m3/s = 2.38306 MGD = 1654.9 gpm
# 	Flow waste = 0.00374 m3/s = 0.08541 MGD = 59.31 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 96.8%
#
# UV AOP:
# 	Total Capital Investment ($MM): 5.17203
# 	Annual O&M ($MM/yr): 0.14064
# 	Annual Fixed O&M ($MM/yr): 0.06887
# 	Annual Chemical Cost ($MM/yr): 0.02762
# 	Annual Electricity Cost ($MM/yr): 0.04415
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.14494
# 	Flow In (m3/s): 0.10441
# 	Flow Out (m3/s): 0.1044
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 1.49478
# 	Annual O&M ($MM/yr): 0.01965
# 	Annual Fixed O&M ($MM/yr): 0.01965
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.03551
# 	Flow In (m3/s): 0.1044
# 	Flow Out (m3/s): 0.10439
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.3055
# 	Annual O&M ($MM/yr): 0.13966
# 	Annual Fixed O&M ($MM/yr): 0.00405
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.1356
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04847
# 	Flow In (m3/s): 0.10439
# 	Flow Out (m3/s): 0.10438
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 2.9976
# 	Annual O&M ($MM/yr): 0.05628
# 	Annual Fixed O&M ($MM/yr): 0.03996
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.01631
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.07634
# 	Flow In (m3/s): 0.00942
# 	Flow Out (m3/s): 0.00942
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 0.8984
# Total Capital Investment ($MM): 36.869
# Total Annual Operating Costs ($MM/yr): 2.821
# Annual Fixed Operating Cost ($MM/yr): 0.49
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.121
# Annual Electricity Costs ($MM/yr): 2.017
# Annual Other Variable Costs ($MM/yr): 0.192
# Treated water (m3/s): 0.184
# Total water recovery (%): 91.247
# Electricity intensity (kWh/m3): 2.591
# Electricity portion of LCOW (%): 38.646
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 2.19939
# 	Annual O&M ($MM/yr): 0.76963
# 	Annual Fixed O&M ($MM/yr): 0.02918
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.74045
# 	Electricity Intensity (kWh/m3): 0.86732
# 	Unit LCOW ($/m3): 0.15711
# 	Flow In (m3/s): 0.20189
# 	Flow Out (m3/s): 0.20187
# 	Flow Waste (m3/s): 2e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 13.14632
# 	Annual O&M ($MM/yr): 0.32871
# 	Annual Fixed O&M ($MM/yr): 0.17505
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.15366
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20379
# 	Flow In (m3/s): 0.20187
# 	Flow Out (m3/s): 0.19178
# 	Flow Waste (m3/s): 0.01009
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 7.65017
# 	Annual O&M ($MM/yr): 1.14074
# 	Annual Fixed O&M ($MM/yr): 0.10187
# 	Annual Chemical Cost ($MM/yr): 0.07275
# 	Annual Electricity Cost ($MM/yr): 0.77425
# 	Electricity Intensity (kWh/m3): 0.95472
# 	Unit LCOW ($/m3): 0.28202
# 	Flow In (m3/s): 0.19178
# 	Flow Out (m3/s): 0.18427
# 	Flow Waste (m3/s): 0.00803
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 28.5 bar = 413 psi
# 	Area = 25583 m2 ---> 688 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 963.235 mg/L
# 	TDS out = 55.159 mg/L
# 	TDS waste = 21740.21 mg/L
# 	Flow in = 0.19178 m3/s = 4.37716 MGD = 3039.7 gpm
# 	Flow out = 0.18427 m3/s = 4.20592 MGD = 2920.78 gpm
# 	Flow waste = 0.00803 m3/s = 0.18327 MGD = 127.27 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 96.1%
#
# UV AOP:
# 	Total Capital Investment ($MM): 6.38235
# 	Annual O&M ($MM/yr): 0.21165
# 	Annual Fixed O&M ($MM/yr): 0.08499
# 	Annual Chemical Cost ($MM/yr): 0.04874
# 	Annual Electricity Cost ($MM/yr): 0.07792
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.1079
# 	Flow In (m3/s): 0.18427
# 	Flow Out (m3/s): 0.18425
# 	Flow Waste (m3/s): 2e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 2.25139
# 	Annual O&M ($MM/yr): 0.02959
# 	Annual Fixed O&M ($MM/yr): 0.02959
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0303
# 	Flow In (m3/s): 0.18425
# 	Flow Out (m3/s): 0.18424
# 	Flow Waste (m3/s): 2e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.49957
# 	Annual O&M ($MM/yr): 0.24596
# 	Annual Fixed O&M ($MM/yr): 0.00663
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.23933
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04793
# 	Flow In (m3/s): 0.18424
# 	Flow Out (m3/s): 0.18422
# 	Flow Waste (m3/s): 2e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 4.73961
# 	Annual O&M ($MM/yr): 0.09458
# 	Annual Fixed O&M ($MM/yr): 0.06319
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.03139
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.06935
# 	Flow In (m3/s): 0.01812
# 	Flow Out (m3/s): 0.01812
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.13405
# Total Capital Investment ($MM): 49.953
# Total Annual Operating Costs ($MM/yr): 6.236
# Annual Fixed Operating Cost ($MM/yr): 0.665
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.175
# Annual Electricity Costs ($MM/yr): 5.12
# Annual Other Variable Costs ($MM/yr): 0.276
# Treated water (m3/s): 0.265
# Total water recovery (%): 91.691
# Electricity intensity (kWh/m3): 4.568
# Electricity portion of LCOW (%): 53.98
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 2.19939
# 	Annual O&M ($MM/yr): 1.09011
# 	Annual Fixed O&M ($MM/yr): 0.02918
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 1.06093
# 	Electricity Intensity (kWh/m3): 0.86732
# 	Unit LCOW ($/m3): 0.14743
# 	Flow In (m3/s): 0.28927
# 	Flow Out (m3/s): 0.28924
# 	Flow Waste (m3/s): 3e-05
# 	Water Recovery (%): 99.99
#
# Well Field 1:
# 	Total Capital Investment ($MM): 1.01822
# 	Annual O&M ($MM/yr): 2.22909
# 	Annual Fixed O&M ($MM/yr): 0.01351
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 2.21559
# 	Electricity Intensity (kWh/m3): 1.81143
# 	Unit LCOW ($/m3): 0.27442
# 	Flow In (m3/s): 0.28924
# 	Flow Out (m3/s): 0.28921
# 	Flow Waste (m3/s): 3e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 18.83433
# 	Annual O&M ($MM/yr): 0.47093
# 	Annual Fixed O&M ($MM/yr): 0.25079
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.22014
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20278
# 	Flow In (m3/s): 0.28921
# 	Flow Out (m3/s): 0.27475
# 	Flow Waste (m3/s): 0.01446
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 11.02695
# 	Annual O&M ($MM/yr): 1.65212
# 	Annual Fixed O&M ($MM/yr): 0.14684
# 	Annual Chemical Cost ($MM/yr): 0.10487
# 	Annual Electricity Cost ($MM/yr): 1.1242
# 	Electricity Intensity (kWh/m3): 0.9676
# 	Unit LCOW ($/m3): 0.28328
# 	Flow In (m3/s): 0.27475
# 	Flow Out (m3/s): 0.26531
# 	Flow Waste (m3/s): 0.0102
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 28.87 bar = 419 psi
# 	Area = 36829 m2 ---> 991 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 898.763 mg/L
# 	TDS out = 57.387 mg/L
# 	TDS waste = 22725.015 mg/L
# 	Flow in = 0.27475 m3/s = 6.27103 MGD = 4354.88 gpm
# 	Flow out = 0.26531 m3/s = 6.05561 MGD = 4205.29 gpm
# 	Flow waste = 0.0102 m3/s = 0.23272 MGD = 161.61 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 96.6%
#
# UV AOP:
# 	Total Capital Investment ($MM): 7.38138
# 	Annual O&M ($MM/yr): 0.28066
# 	Annual Fixed O&M ($MM/yr): 0.09829
# 	Annual Chemical Cost ($MM/yr): 0.07018
# 	Annual Electricity Cost ($MM/yr): 0.11219
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.09096
# 	Flow In (m3/s): 0.26531
# 	Flow Out (m3/s): 0.26529
# 	Flow Waste (m3/s): 3e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 2.928
# 	Annual O&M ($MM/yr): 0.03849
# 	Annual Fixed O&M ($MM/yr): 0.03849
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02737
# 	Flow In (m3/s): 0.26529
# 	Flow Out (m3/s): 0.26526
# 	Flow Waste (m3/s): 3e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.68491
# 	Annual O&M ($MM/yr): 0.35367
# 	Annual Fixed O&M ($MM/yr): 0.00909
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.34458
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04761
# 	Flow In (m3/s): 0.26526
# 	Flow Out (m3/s): 0.26523
# 	Flow Waste (m3/s): 3e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 5.8795
# 	Annual O&M ($MM/yr): 0.12109
# 	Annual Fixed O&M ($MM/yr): 0.07838
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.04271
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.0602
# 	Flow In (m3/s): 0.02466
# 	Flow Out (m3/s): 0.02465
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.13445
# Total Capital Investment ($MM): 97.373
# Total Annual Operating Costs ($MM/yr): 13.679
# Annual Fixed Operating Cost ($MM/yr): 1.296
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.373
# Annual Electricity Costs ($MM/yr): 11.427
# Annual Other Variable Costs ($MM/yr): 0.584
# Treated water (m3/s): 0.559
# Total water recovery (%): 90.98
# Electricity intensity (kWh/m3): 4.834
# Electricity portion of LCOW (%): 57.095
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 2.19939
# 	Annual O&M ($MM/yr): 2.28432
# 	Annual Fixed O&M ($MM/yr): 0.02918
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 2.25515
# 	Electricity Intensity (kWh/m3): 0.86732
# 	Unit LCOW ($/m3): 0.13759
# 	Flow In (m3/s): 0.61488
# 	Flow Out (m3/s): 0.61482
# 	Flow Waste (m3/s): 6e-05
# 	Water Recovery (%): 99.99
#
# Well Field 1:
# 	Total Capital Investment ($MM): 1.01822
# 	Annual O&M ($MM/yr): 4.72302
# 	Annual Fixed O&M ($MM/yr): 0.01351
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 4.70951
# 	Electricity Intensity (kWh/m3): 1.81143
# 	Unit LCOW ($/m3): 0.27147
# 	Flow In (m3/s): 0.61482
# 	Flow Out (m3/s): 0.61475
# 	Flow Waste (m3/s): 6e-05
# 	Water Recovery (%): 99.99
#
# Well Field 2:
# 	Total Capital Investment ($MM): 3.41347
# 	Annual O&M ($MM/yr): 0.49516
# 	Annual Fixed O&M ($MM/yr): 0.04528
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.44987
# 	Electricity Intensity (kWh/m3): 0.17305
# 	Unit LCOW ($/m3): 0.04065
# 	Flow In (m3/s): 0.61475
# 	Flow Out (m3/s): 0.61469
# 	Flow Waste (m3/s): 6e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 40.03076
# 	Annual O&M ($MM/yr): 1.00093
# 	Annual Fixed O&M ($MM/yr): 0.53304
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.46789
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20434
# 	Flow In (m3/s): 0.61469
# 	Flow Out (m3/s): 0.58396
# 	Flow Waste (m3/s): 0.03073
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 23.62625
# 	Annual O&M ($MM/yr): 3.60648
# 	Annual Fixed O&M ($MM/yr): 0.31461
# 	Annual Chemical Cost ($MM/yr): 0.22469
# 	Annual Electricity Cost ($MM/yr): 2.48285
# 	Electricity Intensity (kWh/m3): 1.00545
# 	Unit LCOW ($/m3): 0.29155
# 	Flow In (m3/s): 0.58396
# 	Flow Out (m3/s): 0.55958
# 	Flow Waste (m3/s): 0.02597
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 29.96 bar = 434 psi
# 	Area = 77910 m2 ---> 2097 membrane modules
# 	Flux = 25.9 LMH
# 	TDS in = 1186.727 mg/L
# 	TDS out = 64.513 mg/L
# 	TDS waste = 25291.1 mg/L
# 	Flow in = 0.58396 m3/s = 13.32853 MGD = 9255.92 gpm
# 	Flow out = 0.55958 m3/s = 12.7722 MGD = 8869.58 gpm
# 	Flow waste = 0.02597 m3/s = 0.59283 MGD = 411.69 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 95.8%
#
# UV AOP:
# 	Total Capital Investment ($MM): 10.23139
# 	Annual O&M ($MM/yr): 0.52089
# 	Annual Fixed O&M ($MM/yr): 0.13624
# 	Annual Chemical Cost ($MM/yr): 0.14802
# 	Annual Electricity Cost ($MM/yr): 0.23663
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.06725
# 	Flow In (m3/s): 0.55958
# 	Flow Out (m3/s): 0.55953
# 	Flow Waste (m3/s): 6e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 5.01453
# 	Annual O&M ($MM/yr): 0.06591
# 	Annual Fixed O&M ($MM/yr): 0.06591
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02223
# 	Flow In (m3/s): 0.55953
# 	Flow Out (m3/s): 0.55947
# 	Flow Waste (m3/s): 6e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 1.30681
# 	Annual O&M ($MM/yr): 0.74412
# 	Annual Fixed O&M ($MM/yr): 0.01734
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.72678
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.047
# 	Flow In (m3/s): 0.55947
# 	Flow Out (m3/s): 0.55942
# 	Flow Waste (m3/s): 6e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 10.53262
# 	Annual O&M ($MM/yr): 0.23864
# 	Annual Fixed O&M ($MM/yr): 0.14042
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.09822
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.05236
# 	Flow In (m3/s): 0.05671
# 	Flow Out (m3/s): 0.0567
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# WELL FIELD 3
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# WELL FIELD 3
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.1535
# Total Capital Investment ($MM): 145.838
# Total Annual Operating Costs ($MM/yr): 22.048
# Annual Fixed Operating Cost ($MM/yr): 1.94
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.582
# Annual Electricity Costs ($MM/yr): 18.619
# Annual Other Variable Costs ($MM/yr): 0.907
# Treated water (m3/s): 0.867
# Total water recovery (%): 90.543
# Electricity intensity (kWh/m3): 5.082
# Electricity portion of LCOW (%): 59.041
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 2.19939
# 	Annual O&M ($MM/yr): 3.54078
# 	Annual Fixed O&M ($MM/yr): 0.02918
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 3.5116
# 	Electricity Intensity (kWh/m3): 0.86732
# 	Unit LCOW ($/m3): 0.13475
# 	Flow In (m3/s): 0.95746
# 	Flow Out (m3/s): 0.95736
# 	Flow Waste (m3/s): 0.0001
# 	Water Recovery (%): 99.99
#
# Well Field 1:
# 	Total Capital Investment ($MM): 1.01822
# 	Annual O&M ($MM/yr): 7.34693
# 	Annual Fixed O&M ($MM/yr): 0.01351
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.33342
# 	Electricity Intensity (kWh/m3): 1.81143
# 	Unit LCOW ($/m3): 0.27116
# 	Flow In (m3/s): 0.95736
# 	Flow Out (m3/s): 0.95727
# 	Flow Waste (m3/s): 0.0001
# 	Water Recovery (%): 99.99
#
# Well Field 2:
# 	Total Capital Investment ($MM): 3.41347
# 	Annual O&M ($MM/yr): 0.74581
# 	Annual Fixed O&M ($MM/yr): 0.04528
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.70052
# 	Electricity Intensity (kWh/m3): 0.17305
# 	Unit LCOW ($/m3): 0.0354
# 	Flow In (m3/s): 0.95727
# 	Flow Out (m3/s): 0.95717
# 	Flow Waste (m3/s): 0.0001
# 	Water Recovery (%): 99.99
#
# Well Field 3:
# 	Total Capital Investment ($MM): 3.57674
# 	Annual O&M ($MM/yr): 0.76448
# 	Annual Fixed O&M ($MM/yr): 0.04745
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.71703
# 	Electricity Intensity (kWh/m3): 0.17715
# 	Unit LCOW ($/m3): 0.03647
# 	Flow In (m3/s): 0.95717
# 	Flow Out (m3/s): 0.95707
# 	Flow Waste (m3/s): 0.0001
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 62.32772
# 	Annual O&M ($MM/yr): 1.55844
# 	Annual Fixed O&M ($MM/yr): 0.82994
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.7285
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20531
# 	Flow In (m3/s): 0.95707
# 	Flow Out (m3/s): 0.90922
# 	Flow Waste (m3/s): 0.04785
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 37.06071
# 	Annual O&M ($MM/yr): 5.72809
# 	Annual Fixed O&M ($MM/yr): 0.49351
# 	Annual Chemical Cost ($MM/yr): 0.35246
# 	Annual Electricity Cost ($MM/yr): 3.97464
# 	Electricity Intensity (kWh/m3): 1.03376
# 	Unit LCOW ($/m3): 0.29771
# 	Flow In (m3/s): 0.90922
# 	Flow Out (m3/s): 0.86717
# 	Flow Waste (m3/s): 0.04453
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 30.77 bar = 446 psi
# 	Area = 120998 m2 ---> 3256 membrane modules
# 	Flux = 25.8 LMH
# 	TDS in = 1398.916 mg/L
# 	TDS out = 69.843 mg/L
# 	TDS waste = 27203.902 mg/L
# 	Flow in = 0.90922 m3/s = 20.75247 MGD = 14411.43 gpm
# 	Flow out = 0.86717 m3/s = 19.79267 MGD = 13744.91 gpm
# 	Flow waste = 0.04453 m3/s = 1.01635 MGD = 705.8 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 95.39999999999999%
#
# UV AOP:
# 	Total Capital Investment ($MM): 12.63355
# 	Annual O&M ($MM/yr): 0.7643
# 	Annual Fixed O&M ($MM/yr): 0.16823
# 	Annual Chemical Cost ($MM/yr): 0.22937
# 	Annual Electricity Cost ($MM/yr): 0.3667
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.05802
# 	Flow In (m3/s): 0.86717
# 	Flow Out (m3/s): 0.86708
# 	Flow Waste (m3/s): 9e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 6.87668
# 	Annual O&M ($MM/yr): 0.09039
# 	Annual Fixed O&M ($MM/yr): 0.09039
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01967
# 	Flow In (m3/s): 0.86708
# 	Flow Out (m3/s): 0.867
# 	Flow Waste (m3/s): 9e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 1.90942
# 	Annual O&M ($MM/yr): 1.1516
# 	Annual Fixed O&M ($MM/yr): 0.02533
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 1.12627
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04667
# 	Flow In (m3/s): 0.867
# 	Flow Out (m3/s): 0.86691
# 	Flow Waste (m3/s): 9e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 14.82169
# 	Annual O&M ($MM/yr): 0.35761
# 	Annual Fixed O&M ($MM/yr): 0.1976
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.16001
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.04835
# 	Flow In (m3/s): 0.09238
# 	Flow Out (m3/s): 0.09237
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# WELL FIELD 3
# WELL FIELD 4
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# WELL FIELD 3
# WELL FIELD 4
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.1724
# Total Capital Investment ($MM): 162.596
# Total Annual Operating Costs ($MM/yr): 25.511
# Annual Fixed Operating Cost ($MM/yr): 2.163
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.655
# Annual Electricity Costs ($MM/yr): 21.67
# Annual Other Variable Costs ($MM/yr): 1.022
# Treated water (m3/s): 0.976
# Total water recovery (%): 90.547
# Electricity intensity (kWh/m3): 5.254
# Electricity portion of LCOW (%): 60.048
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# ...
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 10:
# 	Total Capital Investment ($MM): 1.3354
# 	Annual O&M ($MM/yr): 6.9117
# 	Annual Fixed O&M ($MM/yr): 0.01772
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 6.89398
# 	Electricity Intensity (kWh/m3): 1.1909
# 	Unit LCOW ($/m3): 0.17567
# 	Flow In (m3/s): 1.36895
# 	Flow Out (m3/s): 1.36881
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 11:
# 	Total Capital Investment ($MM): 1.32219
# 	Annual O&M ($MM/yr): 7.38501
# 	Annual Fixed O&M ($MM/yr): 0.01754
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.36747
# 	Electricity Intensity (kWh/m3): 1.27282
# 	Unit LCOW ($/m3): 0.18753
# 	Flow In (m3/s): 1.36881
# 	Flow Out (m3/s): 1.36868
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 12:
# 	Total Capital Investment ($MM): 0.36213
# 	Annual O&M ($MM/yr): 10.29333
# 	Annual Fixed O&M ($MM/yr): 0.0048
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 10.28853
# 	Electricity Intensity (kWh/m3): 1.77764
# 	Unit LCOW ($/m3): 0.25896
# 	Flow In (m3/s): 1.36868
# 	Flow Out (m3/s): 1.36854
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 89.12363
# 	Annual O&M ($MM/yr): 2.22844
# 	Annual Fixed O&M ($MM/yr): 1.18675
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 1.04169
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20146
# 	Flow In (m3/s): 1.36854
# 	Flow Out (m3/s): 1.30011
# 	Flow Waste (m3/s): 0.06843
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 57.28962
# 	Annual O&M ($MM/yr): 9.32171
# 	Annual Fixed O&M ($MM/yr): 0.76288
# 	Annual Chemical Cost ($MM/yr): 0.54484
# 	Annual Electricity Cost ($MM/yr): 6.67673
# 	Electricity Intensity (kWh/m3): 1.21444
# 	Unit LCOW ($/m3): 0.32752
# 	Flow In (m3/s): 1.30011
# 	Flow Out (m3/s): 1.26369
# 	Flow Waste (m3/s): 0.04002
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 35.98 bar = 522 psi
# 	Area = 178301 m2 ---> 4798 membrane modules
# 	Flux = 25.5 LMH
# 	TDS in = 1346.071 mg/L
# 	TDS out = 103.24 mg/L
# 	TDS waste = 40465.721 mg/L
# 	Flow in = 1.30011 m3/s = 29.67436 MGD = 20607.19 gpm
# 	Flow out = 1.26369 m3/s = 28.84313 MGD = 20029.95 gpm
# 	Flow waste = 0.04002 m3/s = 0.91351 MGD = 634.38 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 97.2%
#
# UV AOP:
# 	Total Capital Investment ($MM): 15.3236
# 	Annual O&M ($MM/yr): 1.07269
# 	Annual Fixed O&M ($MM/yr): 0.20405
# 	Annual Chemical Cost ($MM/yr): 0.33426
# 	Annual Electricity Cost ($MM/yr): 0.53438
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.05195
# 	Flow In (m3/s): 1.26369
# 	Flow Out (m3/s): 1.26357
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 9.02149
# 	Annual O&M ($MM/yr): 0.11858
# 	Annual Fixed O&M ($MM/yr): 0.11858
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01771
# 	Flow In (m3/s): 1.26357
# 	Flow Out (m3/s): 1.26344
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 2.64531
# 	Annual O&M ($MM/yr): 1.67636
# 	Annual Fixed O&M ($MM/yr): 0.03509
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 1.64127
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.0464
# 	Flow In (m3/s): 1.26344
# 	Flow Out (m3/s): 1.26331
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 16.58238
# 	Annual O&M ($MM/yr): 0.40891
# 	Annual Fixed O&M ($MM/yr): 0.22107
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.18784
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.03734
# 	Flow In (m3/s): 0.10845
# 	Flow Out (m3/s): 0.10844
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# WELL FIELD 3
# WELL FIELD 4
# WELL FIELD 5
# WELL FIELD 6
# WELL FIELD 7
# WELL FIELD 8
# WELL FIELD 9
# WELL FIELD 10
# WELL FIELD 11
# WELL FIELD 12
# WELL FIELD 13
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# WELL FIELD 3
# WELL FIELD 4
# WELL FIELD 5
# WELL FIELD 6
# WELL FIELD 7
# WELL FIELD 8
# WELL FIELD 9
# WELL FIELD 10
# WELL FIELD 11
# WELL FIELD 12
# WELL FIELD 13
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 3.07603
# Total Capital Investment ($MM): 211.123
# Total Annual Operating Costs ($MM/yr): 112.385
# Annual Fixed Operating Cost ($MM/yr): 2.809
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.907
# Annual Electricity Costs ($MM/yr): 107.291
# Annual Other Variable Costs ($MM/yr): 1.378
# Treated water (m3/s): 1.3
# Total water recovery (%): 92.285
# Electricity intensity (kWh/m3): 19.528
# Electricity portion of LCOW (%): 85.071
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field 0:
# 	Total Capital Investment ($MM): 2.1361
# 	Annual O&M ($MM/yr): 4.9086
# 	Annual Fixed O&M ($MM/yr): 0.02834
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 4.88027
# 	Electricity Intensity (kWh/m3): 0.81919
# 	Unit LCOW ($/m3): 0.12311
# 	Flow In (m3/s): 1.4088
# 	Flow Out (m3/s): 1.40866
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 1:
# 	Total Capital Investment ($MM): 2.1044
# 	Annual O&M ($MM/yr): 5.21878
# 	Annual Fixed O&M ($MM/yr): 0.02792
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 5.19087
# 	Electricity Intensity (kWh/m3): 0.87141
# 	Unit LCOW ($/m3): 0.13062
# 	Flow In (m3/s): 1.40866
# 	Flow Out (m3/s): 1.40852
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 2:
# 	Total Capital Investment ($MM): 0.24942
# 	Annual O&M ($MM/yr): 5.14486
# 	Annual Fixed O&M ($MM/yr): 0.00331
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 5.14155
# 	Electricity Intensity (kWh/m3): 0.86322
# 	Unit LCOW ($/m3): 0.12588
# 	Flow In (m3/s): 1.40852
# 	Flow Out (m3/s): 1.40838
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 3:
# 	Total Capital Investment ($MM): 0.97759
# 	Annual O&M ($MM/yr): 7.37996
# 	Annual Fixed O&M ($MM/yr): 0.01297
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.36699
# 	Electricity Intensity (kWh/m3): 1.23698
# 	Unit LCOW ($/m3): 0.18155
# 	Flow In (m3/s): 1.40838
# 	Flow Out (m3/s): 1.40824
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 4:
# 	Total Capital Investment ($MM): 1.10915
# 	Annual O&M ($MM/yr): 7.33219
# 	Annual Fixed O&M ($MM/yr): 0.01471
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.31747
# 	Electricity Intensity (kWh/m3): 1.22878
# 	Unit LCOW ($/m3): 0.18059
# 	Flow In (m3/s): 1.40824
# 	Flow Out (m3/s): 1.4081
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 5:
# 	Total Capital Investment ($MM): 1.49307
# 	Annual O&M ($MM/yr): 7.34265
# 	Annual Fixed O&M ($MM/yr): 0.01981
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.32284
# 	Electricity Intensity (kWh/m3): 1.22981
# 	Unit LCOW ($/m3): 0.18146
# 	Flow In (m3/s): 1.4081
# 	Flow Out (m3/s): 1.40796
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 6:
# 	Total Capital Investment ($MM): 0.92658
# 	Annual O&M ($MM/yr): 7.32221
# 	Annual Fixed O&M ($MM/yr): 0.01229
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.30991
# 	Electricity Intensity (kWh/m3): 1.22776
# 	Unit LCOW ($/m3): 0.18006
# 	Flow In (m3/s): 1.40796
# 	Flow Out (m3/s): 1.40782
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 7:
# 	Total Capital Investment ($MM): 1.06209
# 	Annual O&M ($MM/yr): 6.26256
# 	Annual Fixed O&M ($MM/yr): 0.01409
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 6.24847
# 	Electricity Intensity (kWh/m3): 1.04959
# 	Unit LCOW ($/m3): 0.15443
# 	Flow In (m3/s): 1.40782
# 	Flow Out (m3/s): 1.40768
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 8:
# 	Total Capital Investment ($MM): 1.21275
# 	Annual O&M ($MM/yr): 6.1664
# 	Annual Fixed O&M ($MM/yr): 0.01609
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 6.15031
# 	Electricity Intensity (kWh/m3): 1.0332
# 	Unit LCOW ($/m3): 0.15232
# 	Flow In (m3/s): 1.40768
# 	Flow Out (m3/s): 1.40754
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 9:
# 	Total Capital Investment ($MM): 1.29573
# 	Annual O&M ($MM/yr): 7.36148
# 	Annual Fixed O&M ($MM/yr): 0.01719
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.34429
# 	Electricity Intensity (kWh/m3): 1.2339
# 	Unit LCOW ($/m3): 0.1816
# 	Flow In (m3/s): 1.40754
# 	Flow Out (m3/s): 1.4074
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 10:
# 	Total Capital Investment ($MM): 1.3354
# 	Annual O&M ($MM/yr): 7.10531
# 	Annual Fixed O&M ($MM/yr): 0.01772
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.0876
# 	Electricity Intensity (kWh/m3): 1.1909
# 	Unit LCOW ($/m3): 0.17542
# 	Flow In (m3/s): 1.4074
# 	Flow Out (m3/s): 1.40726
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 11:
# 	Total Capital Investment ($MM): 1.32219
# 	Annual O&M ($MM/yr): 7.59192
# 	Annual Fixed O&M ($MM/yr): 0.01754
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.57438
# 	Electricity Intensity (kWh/m3): 1.27282
# 	Unit LCOW ($/m3): 0.18726
# 	Flow In (m3/s): 1.40726
# 	Flow Out (m3/s): 1.40711
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 12:
# 	Total Capital Investment ($MM): 0.36213
# 	Annual O&M ($MM/yr): 10.58228
# 	Annual Fixed O&M ($MM/yr): 0.0048
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 10.57748
# 	Electricity Intensity (kWh/m3): 1.77764
# 	Unit LCOW ($/m3): 0.25868
# 	Flow In (m3/s): 1.40711
# 	Flow Out (m3/s): 1.40697
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Well Field 13:
# 	Total Capital Investment ($MM): 0.47902
# 	Annual O&M ($MM/yr): 7.3538
# 	Annual Fixed O&M ($MM/yr): 0.00635
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 7.34744
# 	Electricity Intensity (kWh/m3): 1.23493
# 	Unit LCOW ($/m3): 0.18012
# 	Flow In (m3/s): 1.40697
# 	Flow Out (m3/s): 1.40683
# 	Flow Waste (m3/s): 0.00014
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 91.61748
# 	Annual O&M ($MM/yr): 2.2908
# 	Annual Fixed O&M ($MM/yr): 1.21996
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 1.07084
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.20123
# 	Flow In (m3/s): 1.40683
# 	Flow Out (m3/s): 1.33649
# 	Flow Waste (m3/s): 0.07034
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 59.20884
# 	Annual O&M ($MM/yr): 9.6602
# 	Annual Fixed O&M ($MM/yr): 0.78844
# 	Annual Chemical Cost ($MM/yr): 0.56309
# 	Annual Electricity Cost ($MM/yr): 6.93029
# 	Electricity Intensity (kWh/m3): 1.22624
# 	Unit LCOW ($/m3): 0.32955
# 	Flow In (m3/s): 1.33649
# 	Flow Out (m3/s): 1.30051
# 	Flow Waste (m3/s): 0.03969
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 36.32 bar = 527 psi
# 	Area = 183785 m2 ---> 4946 membrane modules
# 	Flux = 25.5 LMH
# 	TDS in = 1331.184 mg/L
# 	TDS out = 105.59 mg/L
# 	TDS waste = 41365.255 mg/L
# 	Flow in = 1.33649 m3/s = 30.5047 MGD = 21183.82 gpm
# 	Flow out = 1.30051 m3/s = 29.68347 MGD = 20613.52 gpm
# 	Flow waste = 0.03969 m3/s = 0.90591 MGD = 629.1 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 97.3%
#
# UV AOP:
# 	Total Capital Investment ($MM): 15.5578
# 	Annual O&M ($MM/yr): 1.10111
# 	Annual Fixed O&M ($MM/yr): 0.20716
# 	Annual Chemical Cost ($MM/yr): 0.344
# 	Annual Electricity Cost ($MM/yr): 0.54995
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.05154
# 	Flow In (m3/s): 1.30051
# 	Flow Out (m3/s): 1.30038
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 9.21022
# 	Annual O&M ($MM/yr): 0.12106
# 	Annual Fixed O&M ($MM/yr): 0.12106
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01757
# 	Flow In (m3/s): 1.30038
# 	Flow Out (m3/s): 1.30025
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 2.7119
# 	Annual O&M ($MM/yr): 1.72506
# 	Annual Fixed O&M ($MM/yr): 0.03598
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 1.68908
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.04638
# 	Flow In (m3/s): 1.30025
# 	Flow Out (m3/s): 1.30012
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 16.75127
# 	Annual O&M ($MM/yr): 0.4139
# 	Annual Fixed O&M ($MM/yr): 0.22332
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.19058
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.03667
# 	Flow In (m3/s): 0.11003
# 	Flow Out (m3/s): 0.11002
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# WELL FIELD 3
# WELL FIELD 4
# WELL FIELD 5
# WELL FIELD 6
# WELL FIELD 7
# WELL FIELD 8
# WELL FIELD 9
# WELL FIELD 10
# WELL FIELD 11
# WELL FIELD 12
# WELL FIELD 13
# WELL FIELD 14
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt INFEASIBLE
#
# Attempt 1:
#
# 	WaterTAP3 solver returned INFEASIBLE solution...
#
# Attempt 2:
#
# 	WaterTAP3 solver returned UNBOUNDED solution...
#
# Attempt 3:
#
# 	WaterTAP3 solver returned UNBOUNDED solution...
#
# WaterTAP3 solution UNBOUNDED
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD 0
# WELL FIELD 1
# WELL FIELD 2
# WELL FIELD 3
# WELL FIELD 4
# WELL FIELD 5
# WELL FIELD 6
# WELL FIELD 7
# WELL FIELD 8
# WELL FIELD 9
# WELL FIELD 10
# WELL FIELD 11
# WELL FIELD 12
# WELL FIELD 13
# WELL FIELD 14
# WELL FIELD 15
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt INFEASIBLE
#
# Attempt 1:

# %%
bw_cluster_lcow['total_lcow'] = lcow_list
bw_cluster_lcow['treatment_lcow'] = treatment_lcow_list
bw_cluster_lcow['bw_transport_lcow'] = bw_transport_lcow_list
bw_cluster_lcow['brine_transport_lcow'] = brine_transport_lcow_list
bw_cluster_lcow['elect_int_new'] = elect_int_list

bw_cluster_lcow.head(3)
# Out:
#   state  state_elec_price cluster_id  centroid_long  centroid_lat  \
# 0    CA             0.134          5    -120.121315     40.145180
# 1    CA             0.134          8    -122.434575     38.247101
# 2    CA             0.134          8    -122.434575     38.247101
#
#    centroid_elev well_count                                       well_id  \
# 0    1251.174927          1                        [USGS-400843120071301]
# 1       3.479558          1                        [USGS-381443122254201]
# 2       3.479558          2  [USGS-381443122254201, USGS-381540122254701]
#
#                          well_elev                     latitude  ...  \
# 0               [[1251.174926758]]               [[40.1451797]]  ...
# 1                  [[4.335468292]]                [[38.245472]]  ...
# 2  [[4.335468292], [10.074157715]]  [[38.245472], [38.2611656]]  ...
#
#                                  elect_int_old  \
# 0                       [[2.3991396084885084]]
# 1                       [[2.6127207018375214]]
# 2  [[2.6127207018375214], [2.071895769159318]]
#
#                                    tds  \
# 0                             [[0.82]]
# 1                        [[1.0231004]]
# 2  [[1.0231004], [0.5395150999999999]]
#
#                                            dist avg_well_yield   avg_tds  \
# 0                                       [[0.0]]       0.132489  0.820000
# 1                        [[0.5740958930743217]]       0.063090  1.023100
# 2  [[0.5740958930743217], [1.6153098312123817]]       0.075708  0.942503
#
#   total_lcow  treatment_lcow  bw_transport_lcow  brine_transport_lcow  \
# 0   0.949256        0.908933           0.000000              0.040323
# 1   1.196602        1.041110           0.089068              0.066425
# 2   1.245739        1.070346           0.117247              0.058147
#
#    elect_int_new
# 0       2.399140
# 1       2.612721
# 2       3.056247
#
# [3 rows x 23 columns]

# %%
elect_int_old_list = []
elect_old_list = []
elect_new_list = []

for idx,row in bw_cluster_lcow.iterrows():
    # Units are kwh/s
    calc_elec_old =  np.multiply(row['well_yield'],row['elect_int_old'])
    calc_elec_new =  np.multiply(row['avg_well_yield'],row['elect_int_new']) 
    # print(calc_elec.sum()/sum(row['well_yield']))
    elect_int_old_list.append(calc_elec_old.sum()/sum(row['well_yield']))
    # Converting to kwh/day
    elect_old_list.append(calc_elec_old.sum())
    elect_new_list.append(calc_elec_new.sum())

bw_cluster_lcow['cum_elect_int_old']= elect_int_old_list

bw_cluster_lcow['elect_old']= elect_old_list
bw_cluster_lcow['elect_new']= elect_new_list

# %%
row = bw_cluster_lcow.tail(1)
# print(row['elect_int_new'].values[0])
# print(row['elect_int_old'].values[0])
print(row['well_yield'])

# print(np.multiply(row['well_yield'].values[0],row['elect_int_old'].values[0]))
# check = np.multiply(row['well_yield'].values[0],row['elect_int_old'].values[0]).sum()
# print('old',check)

# print(row['avg_well_yield'].values[0])
# print('new',row['avg_well_yield'].values[0]*row['elect_int_new'].values[0])
# # print(bw_cluster_lcow['cum_elect_int_old'].sum())
# # print(bw_cluster_lcow['elect_int_new'].sum())
# print(bw_cluster_lcow['elect_old'].sum())
# Out:
# 321    [[0.1072533399999999], [0.0946352999999999], [...
# Name: well_yield, dtype: object
# 321    [[0.1072533399999999], [0.0946352999999999], [...
# Name: well_yield, dtype: object

# %%
bw_cluster_lcow.tail(5)
# Out:
#     state  state_elec_price cluster_id  centroid_long  centroid_lat  \
# 317    CA             0.134         19    -118.788444     34.196124
# 318    CA             0.134         19    -118.788444     34.196124
# 319    CA             0.134         19    -118.788444     34.196124
# 320    CA             0.134         19    -118.788444     34.196124
# 321    CA             0.134         19    -118.788444     34.196124
#
#      centroid_elev well_count  \
# 317     408.500641          5
# 318     408.500641          6
# 319     408.500641          7
# 320     408.500641          8
# 321     408.500641          9
#
#                                                well_id  \
# 317  [USGS-341438119010501, USGS-341253119014601, U...
# 318  [USGS-341438119010501, USGS-341253119014601, U...
# 319  [USGS-341438119010501, USGS-341253119014601, U...
# 320  [USGS-341438119010501, USGS-341253119014601, U...
# 321  [USGS-341438119010501, USGS-341253119014601, U...
#
#                                              well_elev  \
# 317  [[63.963191986], [43.844871521], [18.664432526...
# 318  [[63.963191986], [43.844871521], [18.664432526...
# 319  [[63.963191986], [43.844871521], [18.664432526...
# 320  [[63.963191986], [43.844871521], [18.664432526...
# 321  [[63.963191986], [43.844871521], [18.664432526...
#
#                                               latitude  ... avg_well_yield  \
# 317  [[34.244278], [34.2147255], [34.1958389], [34....  ...       0.643520
# 318  [[34.244278], [34.2147255], [34.1958389], [34....  ...       0.681563
# 319  [[34.244278], [34.2147255], [34.1958389], [34....  ...       0.807744
# 320  [[34.244278], [34.2147255], [34.1958389], [34....  ...       0.907111
# 321  [[34.244278], [34.2147255], [34.1958389], [34....  ...       0.940233
#
#       avg_tds total_lcow treatment_lcow bw_transport_lcow  \
# 317  0.845730   1.802924       1.407532          0.379084
# 318  0.843711   1.870298       1.447297          0.407171
# 319  0.840527   1.961559       1.523856          0.423163
# 320  0.831852   2.054686       1.600990          0.439989
# 321  0.821429   2.119609       1.622941          0.483209
#
#     brine_transport_lcow  elect_int_new     cum_elect_int_old  elect_old  \
# 317             0.016308       6.934530  [2.6863335748185406]   1.728709
# 318             0.015829       7.249238   [2.646099029296687]   1.803484
# 319             0.014540       7.873200  [2.5844727932556113]   2.087592
# 320             0.013706       8.483150   [2.545580877696709]   2.309124
# 321             0.013459       8.657668  [2.5177599918128686]   2.367282
#
#      elect_new
# 317   4.462509
# 318   4.940816
# 319   6.359528
# 320   7.695158
# 321   8.140227
#
# [5 rows x 26 columns]

# %%
# bw_cluster_lcow.to_csv(r'\Users\mhardika\Documents\AMO\GeoToolAll_Methods\Water Source Data\Brackish\centroid_lcow_ca_23Oct23.csv')
# bw_cluster_lcow.to_csv(r'\Users\mhardika\Documents\AMO\GeoToolAll_Methods\Water Source Data\Brackish\centroid_lcow_texas.csv')
# bw_cluster_lcow = pd.read_csv(r'\Users\mhardika\Documents\AMO\GeoToolAll_Methods\Water Source Data\Brackish\centroid_lcow_ca_23Oct23.csv')

# %% [markdown]
# Plot LCOW as a function of number of wells

# %%
# Sorting original brackish water dataframe based on the centroid dataframe
bw_df_temp = bw_df[bw_df['state_alpha']=='TX'].reset_index()

bw_df_temp_1 = bw_df_temp.set_index('unique_site_ID')
bw_df_temp_sorted = bw_df_temp_1.reindex(index =  bw_df_centroid_1['unique_site_ID'] )
bw_df_temp_sorted = bw_df_temp_sorted.reset_index()

# Calculation total old energy

total_old_energy = bw_df_temp_sorted['well_yield']*bw_df_temp_sorted['elec_int']

# %%
bw_df_temp_sorted.head(2)
# bw_df_centroid_1.head(2)
# bw_cluster_lcow_temp.head(2)
# Out:
#          unique_site_ID  index state_alpha county_nm  Latitude  Longitude  \
# 0  USGS-430300087581901    NaN         NaN       NaN       NaN        NaN
# 1  USGS-430255088001801    NaN         NaN       NaN       NaN        NaN
#
#    well_depth_ft  well_yield  TDS_kgm3 state  ...  pipe_lcow  lcow  recovery  \
# 0            NaN         NaN       NaN   NaN  ...        NaN   NaN       NaN
# 1            NaN         NaN       NaN   NaN  ...        NaN   NaN       NaN
#
#    capital  onm  elec_int  tds_out  well_field_o&m  well_field_cap_inv  \
# 0      NaN  NaN       NaN      NaN             NaN                 NaN
# 1      NaN  NaN       NaN      NaN             NaN                 NaN
#
#    well_field_lcow
# 0              NaN
# 1              NaN
#
# [2 rows x 22 columns]

# %%
# Corrected plots!
bw_df_temp_sorted_1 = bw_df_temp_sorted.sort_values('lcow')
# bw_cluster_lcow_temp = bw_cluster_lcow[bw_cluster_lcow['total_lcow']!= 0]

lcow = 0
total_water = 0

fig, ax = plt.subplots()

# Calculating LCOW as a function of well yield without clustering
flow = bw_df_temp_sorted_1['well_yield']*bw_df_temp_sorted_1['recovery']/100
cum_flow = flow.cumsum()

lcow_t = bw_df_temp_sorted_1['lcow'] + bw_df_temp_sorted_1['pipe_lcow']
cost = lcow_t*flow
cum_cost = cost.cumsum()

avg_lcow = np.divide(cum_cost, cum_flow, out=np.zeros_like(cum_cost), where=cum_flow!=0) 
flow

# ax.scatter(cum_flow,avg_lcow)

# for cluster in bw_cluster_lcow_temp['cluster_id'].unique()[0:2]:
#     temp = bw_cluster_lcow_temp[bw_cluster_lcow_temp['cluster_id']==cluster]
    
#     flow = temp['avg_well_yield']*1 # Still need to add system recovery term here!!

#     # cum_flow = flow.cumsum()
#     cost_total_lcow = temp['total_lcow']*flow
#     cum_cost = cost_total_lcow.cumsum()

#     avg_lcow =  np.divide(cum_cost, flow, out=np.zeros_like(cum_cost), where=flow!=0) 
#     print(avg_lcow)

#     ax.scatter(total_water + flow, lcow + avg_lcow, s=80)

#     # if len(avg_lcow)==1:
#     #     lcow = lcow + avg_lcow
#     # else:
#     #     lcow = lcow + avg_lcow[-1]

#     total_water = total_water + temp.tail(1)['avg_well_yield'].values[0]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# dtype: float64

# %%
# Incorrect plots :(
bw_cluster_lcow_temp = bw_cluster_lcow[bw_cluster_lcow['total_lcow']!= 0]

# Column of total old energy
# total_old_energy = 

lcow = 0
total_water = 0
last_elect_int = 0

fig,(ax,ax0) = plt.subplots(1,2,figsize=(12,5))

for cluster in bw_cluster_lcow_temp['cluster_id'].unique():
    temp = bw_cluster_lcow_temp[bw_cluster_lcow_temp['cluster_id']==cluster]

    ax.scatter(total_water + temp['avg_well_yield'],lcow + temp['total_lcow'], s=80)

    ax0.scatter(total_water + temp['avg_well_yield'], last_elect_int + temp['elect_new'], s=80)
   
    lcow = lcow + temp.tail(1)['total_lcow'].values[0]
    total_water = total_water + temp.tail(1)['avg_well_yield'].values[0]
    last_elect_int = last_elect_int + temp.tail(1)['elect_new'].values[0]

    
# ax.scatter(bw_cluster_lcow.index,bw_cluster_lcow['total_lcow'])

ax.scatter(bw_df_temp_sorted['well_yield'].cumsum(),bw_df_temp_sorted['lcow'].cumsum(),label='Without Clustering',color='black',s=80)
ax0.scatter(bw_df_temp['well_yield'].cumsum(),total_old_energy.cumsum(),label='Without Clustering',color='black',s=80)

# ax0.set_ylim([0,20000])

ax.set_ylabel(r'LCOW (\$/m${^3}$)',fontsize=20)
ax0.set_ylabel(r'Energy (kWh/s)',fontsize=20)
ax.set_ylim([0,400])

for a in [ax,ax0]:
    a.set_xlabel(r'Cummulative Water Treated (m${^3}$/s)',fontsize=20)
    a.legend(facecolor = 'white',fontsize=16,frameon=False,loc='upper left')
    a.tick_params(axis='both', which='major', labelsize=20)
    a.set_xlim([0,30])

fig.tight_layout()

# %%
# case_study = 'big_spring'
# scenario = 'dwi_a'
# desired_recovery = 1
# ro_bounds = 'other' # or 'seawater'

# m = watertap_setup(case_study=case_study, scenario=scenario)
# m = get_case_study(m=m)

# # run the baseline watertap3 version of this treatment train
# m = run_watertap3(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds)

# m.fs.reverse_osmosis.membrane_area.unfix()
# m.fs.reverse_osmosis.feed.pressure.unfix()

# # Iterate over each cluster label

# bw_df_centroid_1 = bw_df_centroid[bw_df_centroid['state_alpha']=='TX']

# for centroid in bw_df_centroid_1['cluster_id'].unique():
#     bw_cluster = bw_df_centroid_1[bw_df_centroid["cluster_id"]==centroid]
    
#     # TDS 
#     avg_tds = 0
#     # well yield
#     avg_well_yield  = 0
#     # Iterate over each brackish water site within a cluster
#     for site in bw_cluster.unique_site_ID.unique():
#         # Calculate average well yield
#         avg_well_yield_old = avg_well_yield
#         avg_well_yield = avg_well_yield + bw_cluster[bw_cluster['unique_site_ID']==site]['well_yield'].values[0]

#         # Calculate average TDS
#         avg_tds = (avg_tds*avg_well_yield_old + bw_cluster[bw_cluster['unique_site_ID']==site]['TDS_kgm3'].values[0] * bw_cluster[bw_cluster['unique_site_ID']==site]['well_yield'].values[0])/avg_well_yield
