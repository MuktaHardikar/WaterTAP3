# %% [markdown]
# This file is a copied from a previous brackish water analysis file to update the baseline LCOW to the deep will injection scenarion in the Big Spring Case study

# %%
import matplotlib.pyplot as plt
import pandas as pd
import haversine as hs
import geopandas as gp
from shapely.geometry import Point, Polygon
import numpy as np

from pyomo.environ import Var, Expression, NonNegativeReals, Block, ConcreteModel, Constraint, Objective, Param, maximize, SolverFactory,RangeSet
import pyomo.environ as pyo
from idaes.core import FlowsheetBlock
from pyomo.environ import Block, Expression, units as pyunits
import math
from watertap3.utils import watertap_setup, get_case_study, run_model 
from watertap3.utils import run_watertap3, run_model_no_print, run_and_return_model
from truck_pipe_cost_functions import truck_costing, pipe_costing

# %%
case_study = 'big_spring'
scenario = 'dwi_a'
desired_recovery = 1
ro_bounds = 'other' # or 'seawater'

m = watertap_setup(case_study=case_study, scenario=scenario)
m = get_case_study(m=m)

# run the baseline watertap3 version of this treatment train
m = run_watertap3(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds)

m.fs.reverse_osmosis.membrane_area.unfix()
m.fs.reverse_osmosis.feed.pressure.unfix()

m = run_and_return_model(m, objective=True)

print(m.fs.costing.LCOW())
# Out:
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = BIG SPRING
# Scenario = DWI A
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MICROFILTRATION
# REVERSE OSMOSIS
# UV AOP
# TREATED STORAGE
# MUNICIPAL DRINKING
# DEEP WELL INJECTION
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# BIG SPRING: DWI A
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 0.76073
# Total Capital Investment ($MM): 16.191
# Total Annual Operating Costs ($MM/yr): 0.563
# Annual Fixed Operating Cost ($MM/yr): 0.215
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.046
# Annual Electricity Costs ($MM/yr): 0.243
# Annual Other Variable Costs ($MM/yr): 0.058
# Treated water (m3/s): 0.067
# Total water recovery (%): 89.812
# Electricity intensity (kWh/m3): 2.1
# Electricity portion of LCOW (%): 15.046
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field:
# 	Total Capital Investment ($MM): 0.0
# 	Annual O&M ($MM/yr): 0.00132
# 	Annual Fixed O&M ($MM/yr): 0.0
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00132
# 	Electricity Intensity (kWh/m3): 0.01024
# 	Unit LCOW ($/m3): 0.00062
# 	Flow In (m3/s): 0.075
# 	Flow Out (m3/s): 0.07499
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Microfiltration:
# 	Total Capital Investment ($MM): 4.88375
# 	Annual O&M ($MM/yr): 0.08825
# 	Annual Fixed O&M ($MM/yr): 0.06503
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.02322
# 	Electricity Intensity (kWh/m3): 0.18
# 	Unit LCOW ($/m3): 0.1911
# 	Flow In (m3/s): 0.07499
# 	Flow Out (m3/s): 0.07124
# 	Flow Waste (m3/s): 0.00375
# 	Water Recovery (%): 95.0
#
# Reverse Osmosis:
# 	Total Capital Investment ($MM): 2.9286
# 	Annual O&M ($MM/yr): 0.29123
# 	Annual Fixed O&M ($MM/yr): 0.039
# 	Annual Chemical Cost ($MM/yr): 0.02785
# 	Annual Electricity Cost ($MM/yr): 0.16593
# 	Electricity Intensity (kWh/m3): 1.35417
# 	Unit LCOW ($/m3): 0.22678
# 	Flow In (m3/s): 0.07124
# 	Flow Out (m3/s): 0.06738
# 	Flow Waste (m3/s): 0.00406
#
# 	.....Reverse Osmosis OPERATIONAL PARAMETERS.....
# 	Pressure = 40.0 bar = 580 psi
# 	Area = 7793 m2 ---> 210 membrane modules
# 	Flux = 31.1 LMH
# 	TDS in = 2375.98 mg/L
# 	TDS out = 86.38 mg/L
# 	TDS waste = 40299.651 mg/L
# 	Flow in = 0.07124 m3/s = 1.62608 MGD = 1129.22 gpm
# 	Flow out = 0.06738 m3/s = 1.5379 MGD = 1067.98 gpm
# 	Flow waste = 0.00406 m3/s = 0.09257 MGD = 64.29 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 94.6%
#
# UV AOP:
# 	Total Capital Investment ($MM): 4.45138
# 	Annual O&M ($MM/yr): 0.08868
# 	Annual Fixed O&M ($MM/yr): 0.05927
# 	Annual Chemical Cost ($MM/yr): 0.01782
# 	Annual Electricity Cost ($MM/yr): 0.01159
# 	Electricity Intensity (kWh/m3): 0.1
# 	Unit LCOW ($/m3): 0.17807
# 	Flow In (m3/s): 0.06738
# 	Flow Out (m3/s): 0.06737
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 1.09006
# 	Annual O&M ($MM/yr): 0.01433
# 	Annual Fixed O&M ($MM/yr): 0.01433
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.04013
# 	Flow In (m3/s): 0.06737
# 	Flow Out (m3/s): 0.06737
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.20909
# 	Annual O&M ($MM/yr): 0.03837
# 	Annual Fixed O&M ($MM/yr): 0.00277
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.03559
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.02446
# 	Flow In (m3/s): 0.06737
# 	Flow Out (m3/s): 0.06736
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 2.62825
# 	Annual O&M ($MM/yr): 0.04054
# 	Annual Fixed O&M ($MM/yr): 0.03504
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0055
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.09957
# 	Flow In (m3/s): 0.00781
# 	Flow Out (m3/s): 0.0078
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# 0.7585258937624717

# %%
m.fs.display()
# Out:
# Block fs
#
#   Variables:
#     None
#
#   Objectives:
#     objective_function : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 0.7585258937624717
#
#   Constraints:
#     None
#
#   Blocks:
#     Block fs.costing_param
#
#       Variables:
#         electricity_price : Electricity cost [$/kWh]
#             Size=1, Index=None
#             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#             None :  None : 0.0545 :  None :  True :  True :  Reals
#         maintenance_costs_percent_FCI : Maintenance/contingency cost as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None : 0.008 :  None :  True :  True :  Reals
#         salaries_percent_FCI : Salaries cost as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#             None :  None : 0.0005 :  None :  True :  True :  Reals
#         benefit_percent_of_salary : Benefits cost as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None :   0.9 :  None :  True :  True :  Reals
#         insurance_taxes_percent_FCI : Insurance/taxes cost as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None : 0.002 :  None :  True :  True :  Reals
#         lab_fees_percent_FCI : Lab cost as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None : 0.003 :  None :  True :  True :  Reals
#         land_cost_percent_FCI : Land cost as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#             None :  None : 0.0015 :  None :  True :  True :  Reals
#         plant_lifetime_yrs : Plant lifetime [years
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None :    30 :  None :  True :  True :  Reals
#         plant_cap_utilization : Plant capacity utilization [%]
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None :   1.0 :  None :  True :  True :  Reals
#         working_cap_percent_FCI : Working capital as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None :  0.05 :  None :  True :  True :  Reals
#         wacc : Weighted Average Cost of Capital (WACC)
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None :  0.05 :  None :  True :  True :  Reals
#         contingency_cost_percent_FCI : Contingency costs as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None :     0 :  None :  True :  True :  Reals
#         component_replace_percent_FCI : Component replacement costs as % FCI
#             Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None :     0 :  None :  True :  True :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         None
#     Block fs.water
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         None
#
#       Blocks:
#         Block fs.water.Liq
#
#           Variables:
#             None
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#         Block fs.water.tds
#
#           Variables:
#             None
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#     Block fs.well_field
#
#       Variables:
#         flow_vol_in : Volumetric flowrate of water into unit
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 0.075 : 100.0 : False : False :  Reals
#         conc_mass_in : Mass concentration of species at inlet
#             Size=1, Index=fs.well_field.conc_mass_in_index
#             Key          : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 2.257 :  None : False : False :  Reals
#         temperature_in : Temperature at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_in : Pressure at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         flow_vol_out : Volumetric flowrate of water out of unit
#             Size=1, Index=fs.time
#             Key : Lower : Value     : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.0749925 :  None : False : False :  Reals
#         conc_mass_out : Mass concentration of species at outlet
#             Size=1, Index=fs.well_field.conc_mass_out_index
#             Key          : Lower : Value              : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 2.2572031503150316 :  None : False : False :  Reals
#         temperature_out : Temperature at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_out : Pressure at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         deltaP_outlet : Pressure change between inlet and outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :     0 :  None :  True :  True :  Reals
#         flow_vol_waste : Volumetric flowrate of water in waste
#             Size=1, Index=fs.time
#             Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#             0.0 :  None : 7.499999999993623e-06 :  None : False : False :  Reals
#         conc_mass_waste : Mass concentration of species in waste
#             Size=1, Index=fs.well_field.conc_mass_waste_index
#             Key          : Lower : Value               : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 0.22570000000019194 :  None : False : False :  Reals
#         temperature_waste : Temperature of waste
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_waste : Pressure of waste
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         deltaP_waste : Pressure change between inlet and waste
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :     0 :  None :  True :  True :  Reals
#         water_recovery : Water recovery fraction
#             Size=1, Index=fs.time
#             Key : Lower : Value  : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.9999 :  None :  True :  True :  Reals
#         removal_fraction : Component removal fraction
#             Size=1, Index=fs.well_field.removal_fraction_index
#             Key          : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 1e-05 :  None :  True :  True :  Reals
#         flow_in : Size=1, Index=fs.time
#             Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 5.455873880723015e-06 :  None : False : False : NonNegativeReals
#         lift_height : Lift height for well pump [ft]
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper    : Fixed : Stale : Domain
#             0.0 :     0 :    10 : 100000.0 :  True :  True : NonNegativeReals
#
#       Objectives:
#         None
#
#       Constraints:
#         outlet_pressure_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         waste_pressure_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         recovery_equation : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         flow_balance : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         component_removal_equation : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         component_mass_balance : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         outlet_temperature_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         waste_temperature_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#
#       Blocks:
#         Block fs.well_field.costing
#
#           Variables:
#             tci_reduction : Reduction factor for TCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             tci_uncertainty : Uncertainty for TCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             fci_reduction : Reduction factor for FCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             fci_uncertainty : Uncertainty for FCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             fixed_op_reduction : Reduction factor for Fixed O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             fixed_op_uncertainty : Uncertainty for Fixed O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             annual_op_reduction : Reduction factor for Annual O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             annual_op_uncertainty : Uncertainty for Annual O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             total_op_reduction : Reduction factor for Total O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             total_op_uncertainty : Uncertainty for Total O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             catchem_reduction : Reduction factor for Catalysts/Chemicals
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             catchem_uncertainty : Uncertainty for Catalysts/Chemicals
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             elect_intens_reduction : Reduction factor for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             elect_intens_uncertainty : Uncertainty for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             elect_cost_reduction : Reduction factor for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             elect_cost_uncertainty : Uncertainty for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             other_reduction : Reduction factor for Other capital
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             other_uncertainty : Uncertainty for Other capital
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#     Block fs.microfiltration
#
#       Variables:
#         flow_vol_in : Volumetric flowrate of water into unit
#             Size=1, Index=fs.time
#             Key : Lower : Value     : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 0.0749925 : 100.0 : False : False :  Reals
#         conc_mass_in : Mass concentration of species at inlet
#             Size=1, Index=fs.microfiltration.conc_mass_in_index
#             Key          : Lower : Value              : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 2.2572031503150316 :  None : False : False :  Reals
#         temperature_in : Temperature at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_in : Pressure at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         flow_vol_out : Volumetric flowrate of water out of unit
#             Size=1, Index=fs.time
#             Key : Lower : Value       : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.071242875 :  None : False : False :  Reals
#         conc_mass_out : Mass concentration of species at outlet
#             Size=1, Index=fs.microfiltration.conc_mass_out_index
#             Key          : Lower : Value              : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 2.3759795560879247 :  None : False : False :  Reals
#         temperature_out : Temperature at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_out : Pressure at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         deltaP_outlet : Pressure change between inlet and outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :     0 :  None :  True :  True :  Reals
#         flow_vol_waste : Volumetric flowrate of water in waste
#             Size=1, Index=fs.time
#             Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.0037496250000000064 :  None : False : False :  Reals
#         conc_mass_waste : Mass concentration of species in waste
#             Size=1, Index=fs.microfiltration.conc_mass_waste_index
#             Key          : Lower : Value                  : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 0.00045144063006300557 :  None : False : False :  Reals
#         temperature_waste : Temperature of waste
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_waste : Pressure of waste
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         deltaP_waste : Pressure change between inlet and waste
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :     0 :  None :  True :  True :  Reals
#         water_recovery : Water recovery fraction
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :  0.95 :  None :  True :  True :  Reals
#         removal_fraction : Component removal fraction
#             Size=1, Index=fs.microfiltration.removal_fraction_index
#             Key          : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 1e-05 :  None :  True :  True :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         outlet_pressure_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         waste_pressure_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         recovery_equation : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         flow_balance : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         component_removal_equation : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         component_mass_balance : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         outlet_temperature_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         waste_temperature_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#
#       Blocks:
#         Block fs.microfiltration.costing
#
#           Variables:
#             tci_reduction : Reduction factor for TCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             tci_uncertainty : Uncertainty for TCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             fci_reduction : Reduction factor for FCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             fci_uncertainty : Uncertainty for FCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             fixed_op_reduction : Reduction factor for Fixed O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             fixed_op_uncertainty : Uncertainty for Fixed O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             annual_op_reduction : Reduction factor for Annual O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             annual_op_uncertainty : Uncertainty for Annual O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             total_op_reduction : Reduction factor for Total O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             total_op_uncertainty : Uncertainty for Total O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             catchem_reduction : Reduction factor for Catalysts/Chemicals
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             catchem_uncertainty : Uncertainty for Catalysts/Chemicals
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             elect_intens_reduction : Reduction factor for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             elect_intens_uncertainty : Uncertainty for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             elect_cost_reduction : Reduction factor for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             elect_cost_uncertainty : Uncertainty for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             other_reduction : Reduction factor for Other capital
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             other_uncertainty : Uncertainty for Other capital
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#     Block fs.reverse_osmosis
#
#       Variables:
#         flow_vol_in : Volumetric flowrate of water into unit
#             Size=1, Index=fs.time
#             Key : Lower : Value       : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 0.071242875 : 100.0 : False : False :  Reals
#         conc_mass_in : Mass concentration of species at inlet
#             Size=1, Index=fs.reverse_osmosis.conc_mass_in_index
#             Key          : Lower : Value              : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 2.3759795560879247 :  None : False : False :  Reals
#         temperature_in : Temperature at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_in : Pressure at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         flow_vol_out : Volumetric flowrate of water out of unit
#             Size=1, Index=fs.time
#             Key : Lower : Value               : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.06784191119565237 :  None : False : False :  Reals
#         conc_mass_out : Mass concentration of species at outlet
#             Size=1, Index=fs.reverse_osmosis.conc_mass_out_index
#             Key          : Lower : Value               : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 0.08579678303560548 :  None : False : False :  Reals
#         temperature_out : Temperature at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_out : Pressure at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         deltaP_outlet : Pressure change between inlet and outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :     0 :  None : False :  True :  Reals
#         flow_vol_waste : Volumetric flowrate of water in waste
#             Size=1, Index=fs.time
#             Key : Lower : Value                : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.003594657939932434 :  None : False : False :  Reals
#         conc_mass_waste : Mass concentration of species in waste
#             Size=1, Index=fs.reverse_osmosis.conc_mass_waste_index
#             Key          : Lower : Value             : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 45.47052863239208 :  None : False : False :  Reals
#         temperature_waste : Temperature of waste
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_waste : Pressure of waste
#             Size=1, Index=fs.time
#             Key : Lower : Value             : Upper : Fixed : Stale : Domain
#             0.0 :  None : 41.78627129574071 :  None : False : False :  Reals
#         deltaP_waste : Pressure change between inlet and waste
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :     0 :  None : False :  True :  Reals
#         water_recovery : Water recovery fraction
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   0.8 :  None : False :  True :  Reals
#         removal_fraction : Component removal fraction
#             Size=1, Index=fs.reverse_osmosis.removal_fraction_index
#             Key          : Lower : Value    : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 0.973097 :  None :  True :  True :  Reals
#         pure_water_flux : water flux
#             Size=1, Index=fs.time
#             Key : Lower : Value                : Upper : Fixed : Stale : Domain
#             0.0 : 0.001 : 0.009710271586166427 : 0.015 : False : False : NonNegativeReals
#         a : water permeability
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     1 :   4.2 :     9 :  True :  True : NonNegativeReals
#         b : Salt permeability
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :   0.1 :  0.35 :   0.9 :  True :  True : NonNegativeReals
#         mem_cost : Membrane cost
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :    10 :    30 :    80 :  True :  True : NonNegativeReals
#         membrane_area : area
#             Size=1, Index=fs.time
#             Key : Lower : Value             : Upper           : Fixed : Stale : Domain
#             0.0 :  10.0 : 6951.536075252799 : 1000000000000.0 : False : False : NonNegativeReals
#         factor_membrane_replacement : replacement rate membrane fraction
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  0.01 :  0.25 :     3 :  True :  True : NonNegativeReals
#         pressure_vessel_cost : Size=1, Index=fs.time
#             Key : Lower : Value              : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 172067.73940360494 :  None : False : False : NonNegativeReals
#         rack_support_cost : Size=1, Index=fs.time
#             Key : Lower : Value             : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 66584.34399808735 :  None : False : False : NonNegativeReals
#
#       Objectives:
#         None
#
#       Constraints:
#         component_mass_balance : Size=1
#             Key          : Lower : Body                   : Upper
#             (0.0, 'tds') :   0.0 : 1.1641532182693481e-10 :   0.0
#         outlet_temperature_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         waste_temperature_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         water_salt_perm_eq1 : Size=1
#             Key  : Lower : Body                 : Upper
#             None :  None : -0.08325000000000005 :   0.0
#         water_salt_perm_eq2 : Size=1
#             Key  : Lower : Body                 : Upper
#             None :  None : -0.09004999999999996 :   0.0
#         momentum_balance_eq : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         flow_vol_eq1 : Size=1
#             Key  : Lower : Body                    : Upper
#             None :   0.0 : -1.4210854715202004e-14 :   0.0
#         flow_vol_eq2 : Size=1
#             Key  : Lower : Body                   : Upper
#             None :   0.0 : -4.440892098500626e-16 :   0.0
#         pressure_waste_outlet_eq : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         mass_balance_H2O : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         mass_balance_tds : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         p_out_eq : Size=1
#             Key  : Lower : Body : Upper
#             None :   1.0 :  1.0 :   1.0
#         pump_constraint_power : Size=1
#             Key  : Lower : Body              : Upper
#             None :   0.0 : 389932.4815798179 :  None
#         pressure_vessel_cost_eq : Size=1
#             Key  : Lower : Body                : Upper
#             None :  None : -3441.3398717510863 :   0.0
#         rack_support_cost_eq : Size=1
#             Key  : Lower : Body               : Upper
#             None :  None : -1331.672062729107 :   0.0
#         pressure_vessel_cost_eq2 : Size=1
#             Key  : Lower : Body                  : Upper
#             None :  None : -0.014916321029886603 :   0.0
#         rack_support_cost_eq2 : Size=1
#             Key  : Lower : Body                  : Upper
#             None :  None : -0.014817232644418254 :   0.0
#
#       Blocks:
#         Block fs.reverse_osmosis.costing
#
#           Variables:
#             tci_reduction : Reduction factor for TCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             tci_uncertainty : Uncertainty for TCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             fci_reduction : Reduction factor for FCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             fci_uncertainty : Uncertainty for FCI
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             fixed_op_reduction : Reduction factor for Fixed O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             fixed_op_uncertainty : Uncertainty for Fixed O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             annual_op_reduction : Reduction factor for Annual O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             annual_op_uncertainty : Uncertainty for Annual O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             total_op_reduction : Reduction factor for Total O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             total_op_uncertainty : Uncertainty for Total O&M
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             catchem_reduction : Reduction factor for Catalysts/Chemicals
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             catchem_uncertainty : Uncertainty for Catalysts/Chemicals
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             elect_intens_reduction : Reduction factor for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             elect_intens_uncertainty : Uncertainty for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             elect_cost_reduction : Reduction factor for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             elect_cost_uncertainty : Uncertainty for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             other_reduction : Reduction factor for Other capital
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             other_uncertainty : Uncertainty for Other capital
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#         Block fs.reverse_osmosis.permeate
#
#           Variables:
#             mass_flow_H2O : mass flow rate
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 67.50130323173813 :  None : False : False : NonNegativeReals
#             mass_flow_tds : mass flow rate
#                 Size=1, Index=fs.time
#                 Key : Lower : Value                : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 0.005820617735574201 :  None : False : False : NonNegativeReals
#             mass_frac_H2O : mass_fraction
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :  None :  None :  None : False :  True :  Reals
#             mass_frac_tds : mass_fraction
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 86.22227408996005 :  None : False : False :  Reals
#             conc_mass_H2O : H2O mass density
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :  None :  None : False :  True : NonNegativeReals
#             conc_mass_total : density
#                 Size=1, Index=fs.time
#                 Key : Lower : Value            : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 995.065184039212 :  None : False : False : NonNegativeReals
#             osm_coeff : Osmotic pressure coefficient
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :  None :   0.1 :  None : False :  True :  Reals
#             pressure_osm : Osmotic pressure
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :  None :  None : False :  True : NonNegativeReals
#             pressure : pressure
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     2 :    45 :    90 : False :  True : NonNegativeReals
#
#           Objectives:
#             None
#
#           Constraints:
#             eq1 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq2 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq3 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq4 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq5 : Size=1
#                 Key  : Lower : Body                   : Upper
#                 None :   0.0 : -9.094947017729282e-13 :   0.0
#             eq6 : Size=1
#                 Key  : Lower : Body                  : Upper
#                 None :   0.0 : 1.734723475976807e-18 :   0.0
#         Block fs.reverse_osmosis.feed
#
#           Variables:
#             water_flux : water flux
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 : 1e-05 : 0.005 : 0.015 : False :  True : NonNegativeReals
#             mass_flow_H2O : mass flow rate
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 71.02798787606615 :  None : False : False : NonNegativeReals
#             mass_flow_tds : mass flow rate
#                 Size=1, Index=fs.time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 0.1692716145169275 :  None : False : False : NonNegativeReals
#             mass_frac_H2O : mass_fraction
#                 Size=1, Index=fs.time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 0.9976224981729905 :  None : False : False :  Reals
#             mass_frac_tds : mass_fraction
#                 Size=1, Index=fs.time
#                 Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 0.0023775018270094546 :  None : False : False :  Reals
#             conc_mass_H2O : H2O mass density
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 996.9837387397148 :  None : False : False : NonNegativeReals
#             conc_mass_total : density
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 999.3597182958027 :  None : False : False : NonNegativeReals
#             osm_coeff : Osmotic pressure coefficient
#                 Size=1, Index=fs.time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 0.9182391702859134 :  None : False : False :  Reals
#             pressure_osm : Osmotic pressure
#                 Size=1, Index=fs.time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 1.8491287396704539 :  None : False : False : NonNegativeReals
#             pressure : pressure
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :     2 : 44.78627129574071 :    90 : False : False : NonNegativeReals
#
#           Objectives:
#             None
#
#           Constraints:
#             eq1 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq2 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq3 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq4 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq5 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq6 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq7 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq8 : Size=1
#                 Key  : Lower : Body                    : Upper
#                 None :   0.0 : -2.9103830456733704e-11 :   0.0
#         Block fs.reverse_osmosis.retentate
#
#           Variables:
#             water_flux : water flux
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 : 1e-05 : 0.005 : 0.015 : False :  True : NonNegativeReals
#             mass_flow_H2O : mass flow rate
#                 Size=1, Index=fs.time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 3.5266846443280158 :  None : False : False : NonNegativeReals
#             mass_flow_tds : mass flow rate
#                 Size=1, Index=fs.time
#                 Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 0.16345099678135327 :  None : False : False : NonNegativeReals
#             mass_frac_H2O : mass_fraction
#                 Size=1, Index=fs.time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 0.9557059651248443 :  None : False : False :  Reals
#             mass_frac_tds : mass_fraction
#                 Size=1, Index=fs.time
#                 Key : Lower : Value               : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 0.04429403487515566 :  None : False : False :  Reals
#             conc_mass_H2O : H2O mass density
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 981.0904690403738 :  None : False : False : NonNegativeReals
#             conc_mass_total : density
#                 Size=1, Index=fs.time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 1026.5609976727658 :  None : False : False : NonNegativeReals
#             osm_coeff : Osmotic pressure coefficient
#                 Size=1, Index=fs.time
#                 Key : Lower : Value              : Upper : Fixed : Stale : Domain
#                 0.0 :  None : 0.9315905904059671 :  None : False : False :  Reals
#             pressure_osm : Osmotic pressure
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :     0 : 36.48402534625656 :  None : False : False : NonNegativeReals
#             pressure : pressure
#                 Size=1, Index=fs.time
#                 Key : Lower : Value             : Upper : Fixed : Stale : Domain
#                 0.0 :     2 : 41.78627129574071 :    90 : False : False : NonNegativeReals
#
#           Objectives:
#             None
#
#           Constraints:
#             eq1 : Size=1
#                 Key  : Lower : Body                    : Upper
#                 None :   0.0 : -2.2737367544323206e-13 :   0.0
#             eq2 : Size=1
#                 Key  : Lower : Body                   : Upper
#                 None :   0.0 : 1.1368683772161603e-13 :   0.0
#             eq3 : Size=1
#                 Key  : Lower : Body                   : Upper
#                 None :   0.0 : -7.105427357601002e-15 :   0.0
#             eq4 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq5 : Size=1
#                 Key  : Lower : Body : Upper
#                 None :   0.0 :  0.0 :   0.0
#             eq6 : Size=1
#                 Key  : Lower : Body                  : Upper
#                 None :   0.0 : 4.656612873077393e-10 :   0.0
#     Block fs.uv_aop
#
#       Variables:
#         flow_vol_in : Volumetric flowrate of water into unit
#             Size=1, Index=fs.time
#             Key : Lower : Value               : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 0.06784191119565237 : 100.0 : False : False :  Reals
#         conc_mass_in : Mass concentration of species at inlet
#             Size=1, Index=fs.uv_aop.conc_mass_in_index
#             Key          : Lower : Value               : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 0.08579678303560548 :  None : False : False :  Reals
#         temperature_in : Temperature at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_in : Pressure at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         flow_vol_out : Volumetric flowrate of water out of unit
#             Size=1, Index=fs.time
#             Key : Lower : Value               : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.06783512700453281 :  None : False : False :  Reals
#         conc_mass_out : Mass concentration of species at outlet
#             Size=1, Index=fs.uv_aop.conc_mass_out_index
#             Key          : Lower : Value               : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 0.08580450551832695 :  None : False : False :  Reals
#         temperature_out : Temperature at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
# ...
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             elect_cost_uncertainty : Uncertainty for Electricity Intensity
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#             other_reduction : Reduction factor for Other capital
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#             other_uncertainty : Uncertainty for Other capital
#                 Size=1, Index=fs.time
#                 Key : Lower : Value : Upper : Fixed : Stale : Domain
#                 0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#     Block fs.big_spring_feed
#
#       Variables:
#         flow_vol_in : Volumetric flowrate of water into unit
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 0.075 :  None :  True :  True : NonNegativeReals
#         conc_mass_in : Mass concentration of species at inlet
#             Size=1, Index=fs.big_spring_feed.conc_mass_in_index
#             Key          : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :     0 : 2.257 :  None :  True :  True : NonNegativeReals
#         temperature_in : Temperature at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   300 :  None :  True :  True :  Reals
#         pressure_in : Pressure at inlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :     1 :  None :  True :  True :  Reals
#         flow_vol_out : Volumetric flowrate of water out of unit
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 : 0.075 :  None : False : False : NonNegativeReals
#         conc_mass_out : Mass concentration of species at outlet
#             Size=1, Index=fs.big_spring_feed.conc_mass_out_index
#             Key          : Lower : Value : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :     0 : 2.257 :  None : False : False : NonNegativeReals
#         temperature_out : Temperature at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_out : Pressure at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         tds_eq : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         eq_flow : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         eq_temp : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#         eq_pres : Size=1
#             Key  : Lower : Body : Upper
#             None :   0.0 :  0.0 :   0.0
#     Block fs.mixer1
#
#       Variables:
#         flow_vol_inlet1 : Volumetric flowrate of water out of unit
#             Size=1, Index=fs.time
#             Key : Lower : Value                 : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.0037496250000000064 :  None : False : False :  Reals
#         conc_mass_inlet1 : Mass concentration of species at outlet
#             Size=1, Index=fs.mixer1.conc_mass_inlet1_index
#             Key          : Lower : Value                  : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 0.00045144063006300557 :  None : False : False :  Reals
#         pressure_inlet1 : Pressure at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None :   1.0 :  None : False : False :  Reals
#         temperature_inlet1 : Temperature at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         flow_vol_inlet2 : Volumetric flowrate of water out of unit
#             Size=1, Index=fs.time
#             Key : Lower : Value                : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.003594657939932434 :  None : False : False :  Reals
#         conc_mass_inlet2 : Mass concentration of species at outlet
#             Size=1, Index=fs.mixer1.conc_mass_inlet2_index
#             Key          : Lower : Value             : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 45.47052863239208 :  None : False : False :  Reals
#         pressure_inlet2 : Pressure at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value             : Upper : Fixed : Stale : Domain
#             0.0 :  None : 41.78627129574071 :  None : False : False :  Reals
#         temperature_inlet2 : Temperature at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         flow_vol_out : Volumetric flowrate of water out of unit
#             Size=1, Index=fs.time
#             Key : Lower : Value                : Upper : Fixed : Stale : Domain
#             0.0 :  None : 0.007344282939932441 :  None : False : False :  Reals
#         conc_mass_out : Mass concentration of species at outlet
#             Size=1, Index=fs.mixer1.conc_mass_out_index
#             Key          : Lower : Value              : Upper : Fixed : Stale : Domain
#             (0.0, 'tds') :  None : 22.255772394837685 :  None : False : False :  Reals
#         temperature_out : Temperature at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :  None : 300.0 :  None : False : False :  Reals
#         pressure_out : Pressure at outlet
#             Size=1, Index=fs.time
#             Key : Lower : Value              : Upper : Fixed : Stale : Domain
#             0.0 :  None : 21.393135647870356 :  None : False : False :  Reals
#
#       Objectives:
#         None
#
#       Constraints:
#         flow_balance : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         component_mass_balance : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         outlet_temperature_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         outlet_pressure_constraint : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#
#       Blocks:
#         Block fs.mixer1.inlet1_state[0.0]
#
#           Variables:
#             None
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#         Block fs.mixer1.inlet2_state[0.0]
#
#           Variables:
#             None
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#         Block fs.mixer1.mixed_state[0.0]
#
#           Variables:
#             None
#
#           Objectives:
#             None
#
#           Constraints:
#             None
#     Block fs.costing
#
#       Variables:
#         sys_tci_reduction : System TCI reduction factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#         sys_catchem_reduction : System catalyst/chemical cost reduction factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#         sys_elect_reduction : System electricity cost reduction factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#         sys_other_reduction : System other cost reduction factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#         sys_fixed_op_reduction : System fixed O&M reduction factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#         sys_total_op_reduction : System total O&M reduction factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     0 :  None :  True :  True : NonNegativeReals
#         sys_tci_uncertainty : System TCI uncertainty factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#         sys_catchem_uncertainty : System catalyst/chemical cost uncertainty factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#         sys_elect_uncertainty : System electricity cost uncertainty factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#         sys_other_uncertainty : System other cost uncertainty factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#         sys_fixed_op_uncertainty : System fixed O&M uncertainty factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#         sys_total_op_uncertainty : System total O&M uncertainty factor
#             Size=1, Index=fs.time
#             Key : Lower : Value : Upper : Fixed : Stale : Domain
#             0.0 :     0 :     1 :  None :  True :  True : NonNegativeReals
#
#       Objectives:
#         None
#
#       Constraints:
#         None
#     Block fs.arc1_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#     Block fs.arc2_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#     Block fs.arc3_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#     Block fs.arc5_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#     Block fs.arc7_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#     Block fs.arc8_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#     Block fs.arc9_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#     Block fs.arc10_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#     Block fs.arc11_expanded
#
#       Variables:
#         None
#
#       Objectives:
#         None
#
#       Constraints:
#         conc_mass_equality : Size=1
#             Key          : Lower : Body : Upper
#             (0.0, 'tds') :   0.0 :  0.0 :   0.0
#         flow_vol_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         pressure_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0
#         temperature_equality : Size=1
#             Key : Lower : Body : Upper
#             0.0 :   0.0 :  0.0 :   0.0

# %%
# Read in brackish database. It is filtered for the correct columns. 
df = pd.read_csv('/Users/mhardika/Documents/AMO/GeoToolAll_Methods/Water Source Data/Brackish/USGS_brackish_filtered.csv', index_col='unique_site_ID')

# convert USGS unit to our units: gpm to m3s, 
df.well_yield = df.well_yield * 6.30902e-5 #gpm to m3s
df.TDS_mgL = df.TDS_mgL / 1000 #mgL to kg/m3
df = df.rename(columns={'TDS_mgL': 'TDS_kgm3'})

path = 'C:/Users/mhardika/Documents/watertap3/WaterTAP3/watertap3/watertap3/data'

# add state look up for elec prices and add elec price column
state_abbv_df = pd.read_csv(path + '/state_abbv.csv', index_col='abbv')
elec_price_df = pd.read_csv(path + '/industrial_electricity_costs_2020.csv', index_col='location')
df['state'] = df.state_alpha.map(state_abbv_df.us_state)
df['elec_price'] = df.state.map(elec_price_df.cost)

# filter for well of interest in the US
df = df[df.well_yield >= 0.01]
df = df[df.TDS_kgm3 >= 0.5]
df = df[df.Latitude >= 22]
df = df[df.Longitude >= -150]
df = df[df.TDS_kgm3 <= 25]

# loop through brackish sites and calculate+save LCOW, capital, O&M, energy intensity, and recovery in a df.
capital = []
recovery = []
onm = []
lcow = []
pipe_cost = []
elec_int = []
tds_out = []
flow_in_list = []
tds_in_list = []
i = 0

for site in df.index:
    print('-----------------------------')
    print('SITE NAME:', site)
    i = i + 1
    print(i/len(df.index))
           
    m.fs.big_spring_feed.flow_vol_in.fix(df.loc[site].well_yield)
    m.fs.big_spring_feed.conc_mass_in[0, 'tds'].fix(df.loc[site].TDS_kgm3)
    m.fs.well_field.lift_height.fix(df.loc[site].well_depth_ft)
    
    m.fs.costing_param.electricity_price = df.loc[site].elec_price

    m = run_and_return_model(m, objective=True)

    temp = pipe_costing(m.fs.deep_well_injection.flow_vol_in[0].value*3600*24,10)*(1-m.fs.costing.system_recovery())
    
    flow_in_list.append(df.loc[site].well_yield)
    capital.append(m.fs.costing.capital_investment_total())
    recovery.append(m.fs.costing.system_recovery()*100)
    onm.append(m.fs.costing.operating_cost_annual())
    pipe_cost.append(temp)
    lcow.append(m.fs.costing.LCOW())
    elec_int.append(m.fs.costing.electricity_intensity())
    tds_out.append(m.fs.municipal_drinking.conc_mass_in[0, 'tds']())
    tds_in_list.append(df.loc[site].TDS_kgm3)
    
df['lcow'] = lcow
df['pipe_cost'] = pipe_cost
df['recovery'] = recovery
df['capital'] = capital
df['onm'] = onm
df['elec_int'] = elec_int
df['tds_out'] = tds_out
# Out:
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0183
# 0.0001953506544246923
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0274
# 0.0003907013088493846
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0297
# 0.000586051963274077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0327
# 0.0007814026176987692
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0338
# 0.0009767532721234617
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0373
# 0.001172103926548154
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0411
# 0.0013674545809728462
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0412
# 0.0015628052353975385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0425
# 0.0017581558898222308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0464
# 0.0019535065442469234
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0467
# 0.0021488571986716157
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0468
# 0.002344207853096308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0474
# 0.0025395585075210004
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0475
# 0.0027349091619456923
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0725
# 0.0029302598163703846
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ1064
# 0.003125610470795077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ1086
# 0.0033209611252197693
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ1090
# 0.0035163117796444617
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ1099
# 0.003711662434069154
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: CO_GEOTH-16-03
# 0.003907013088493847
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: CO_GEOTH-59-09
# 0.004102363742918539
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-261730N0974730.1
# 0.0042977143973432315
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-262920N0974650.1
# 0.004493065051767923
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-270500N0822000.1
# 0.004688415706192616
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-291610N1003320.1
# 0.004883766360617308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-292140N0950400.1
# 0.005079117015042001
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-294000N0813400.1
# 0.005274467669466693
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-304300N0880100.1
# 0.005469818323891385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-311340N0970030.1
# 0.005665168978316077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-311620N1033000.1
# 0.005860519632740769
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-312720N1032430.1
# 0.006055870287165462
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-315303N1073340.1
# 0.006251220941590154
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-315940N1050840.1
# 0.006446571596014847
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-320300N0873200.1
# 0.006641922250439539
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-322030N1040940.1
# 0.006837272904864231
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-322300N0945230.1
# 0.007032623559288923
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-322300N0965030.1
# 0.007227974213713616
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-325259N1134114.1
# 0.007423324868138308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-325600N1092600.1
# 0.007618675522563001
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-325816N1132449.1
# 0.007814026176987694
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-325910N1060120.1
# 0.008009376831412385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-330730N0912500.1
# 0.008204727485837077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-331928N1114800.1
# 0.00840007814026177
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-332000N0791500.1
# 0.008595428794686463
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-332800N0865900.1
# 0.008790779449111155
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-333800N0865900.1
# 0.008986130103535847
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-335610N1142419.1
# 0.009181480757960539
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-335812N0902211.1
# 0.009376831412385232
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-341230N1064900.1
# 0.009572182066809924
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-343700N1000430.1
# 0.009767532721234616
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-345115N1064200.1
# 0.009962883375659308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-351530N0912545.1
# 0.010158234030084002
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-351645N1075900.1
# 0.010353584684508694
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-352320N1055740.1
# 0.010548935338933385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-352950N1085240.1
# 0.010744285993358077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-353200N0973300.1
# 0.01093963664778277
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-354600N0771200.1
# 0.011134987302207463
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-364000N0761700.1
# 0.011330337956632155
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-370000N1082100.1
# 0.011525688611056847
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-380600N1032600.1
# 0.011721039265481539
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-381000N1023200.1
# 0.011916389919906232
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-381236N0812523.1
# 0.012111740574330924
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-381600N1022900.1
# 0.012307091228755616
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-382300N1085700.1
# 0.012502441883180308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-382525N0845303.1
# 0.012697792537605002
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-383100N1183600.1
# 0.012893143192029694
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-383800N1023600.1
# 0.013088493846454385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-385700N1031800.1
# 0.013283844500879077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-390000N0745000.1
# 0.013479195155303771
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-391600N1155900.1
# 0.013674545809728463
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-393300N0891730.1
# 0.013869896464153155
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-394900N1081000.1
# 0.014065247118577847
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-395200N0805000.1
# 0.01426059777300254
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-395300N0830500.1
# 0.014455948427427232
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-395800N0830200.1
# 0.014651299081851924
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-402000N0793700.1
# 0.014846649736276616
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-402023N1033420.2
# 0.01504200039070131
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-402238N1043713.1
# 0.015237351045126002
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-402800N1042900.1
# 0.015432701699550693
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-402900N1044622.2
# 0.015628052353975387
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-404430N0845630.1
# 0.01582340300840008
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-404844N1025311.1
# 0.01601875366282477
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-405430N0983700.1
# 0.016214104317249463
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-405800N0902130.1
# 0.016409454971674155
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-410315N1020520.1
# 0.016604805626098847
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-411800N0890400.1
# 0.01680015628052354
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-412800N0915000.1
# 0.01699550693494823
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-413030N0903030.1
# 0.017190857589372926
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-413042N0830818.1
# 0.017386208243797618
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-413900N0951900.1
# 0.01758155889822231
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-414900N0875400.1
# 0.017776909552647
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-420235N0970830.1
# 0.017972260207071693
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-424100N1194130.1
# 0.018167610861496385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-425000N1025945.1
# 0.018362961515921077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-425208N0835351.1
# 0.01855831217034577
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-425637N0854107.1
# 0.018753662824770465
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-430014N0854109.1
# 0.018949013479195156
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-430053N0834234.1
# 0.01914436413361985
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-431500N0834740.1
# 0.01933971478804454
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-432453N0843633.1
# 0.019535065442469232
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-434855N1171440.1
# 0.019730416096893924
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-440957N0981026.1
# 0.019925766751318616
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-441621N0833100.1
# 0.020121117405743308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-441906N0964810.1
# 0.020316468060168003
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-442500N0954800.1
# 0.020511818714592695
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-451215N1035151.1
# 0.020707169369017387
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-451830N1072200.1
# 0.02090252002344208
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-453235N1224910.1
# 0.02109787067786677
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-454630N0993702.1
# 0.021293221332291463
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-455630N0845422.1
# 0.021488571986716155
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-460000N1092200.1
# 0.021683922641140847
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-475600N1103600.1
# 0.02187927329556554
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-480300N1060200.1
# 0.022074623949990234
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-480930N1043100.1
# 0.022269974604414926
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-481200N1083800.1
# 0.022465325258839618
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-481500N1011900.1
# 0.02266067591326431
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-484700N1043300.1
# 0.022856026567689
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-485100N0964800.1
# 0.023051377222113693
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-1732
# 0.023246727876538385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-1733
# 0.023442078530963077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-19069
# 0.023637429185387773
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-2141
# 0.023832779839812464
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-2435
# 0.024028130494237156
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-282
# 0.02422348114866185
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-3044
# 0.02441883180308654
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-436
# 0.024614182457511232
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: GBGGD-700
# 0.024809533111935924
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00152
# 0.025004883766360616
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00176
# 0.02520023442078531
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00187
# 0.025395585075210003
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00247
# 0.025590935729634695
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00304
# 0.025786286384059387
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00310
# 0.02598163703848408
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00334
# 0.02617698769290877
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00337
# 0.026372338347333463
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00366
# 0.026567689001758155
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00622
# 0.026763039656182847
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00732
# 0.026958390310607542
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00766
# 0.027153740965032234
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00823
# 0.027349091619456926
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00842
# 0.027544442273881618
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL00937
# 0.02773979292830631
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01004
# 0.027935143582731
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01050
# 0.028130494237155693
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01122
# 0.028325844891580385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01137
# 0.02852119554600508
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01175
# 0.028716546200429773
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01184
# 0.028911896854854464
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01408
# 0.029107247509279156
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01449
# 0.029302598163703848
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL01543
# 0.02949794881812854
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL11047
# 0.029693299472553232
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL11495
# 0.029888650126977924
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL11507
# 0.03008400078140262
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL11526
# 0.03027935143582731
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL11600
# 0.030474702090252003
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: IL_EPA-ilWL11636
# 0.030670052744676695
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: MT_GEOTH-MGEOT258
# 0.030865403399101387
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-CA13
# 0.03106075405352608
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-CB09
# 0.031256104707950774
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-CB10
# 0.031451455362375466
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA01
# 0.03164680601680016
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA05
# 0.03184215667122485
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA07
# 0.03203750732564954
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA08
# 0.032232857980074234
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA09
# 0.032428208634498926
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA12
# 0.03262355928892362
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA15
# 0.03281890994334831
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA16
# 0.033014260597773
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA17
# 0.03320961125219769
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA19
# 0.033404961906622385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA23
# 0.03360031256104708
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA25
# 0.03379566321547177
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA26
# 0.03399101386989646
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA27
# 0.03418636452432116
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA36
# 0.03438171517874585
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA41
# 0.034577065833170544
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA51
# 0.034772416487595235
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA52
# 0.03496776714201993
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA56
# 0.03516311779644462
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA57
# 0.03535846845086931
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA58
# 0.035553819105294
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-DA60
# 0.035749169759718695
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-HD10
# 0.03594452041414339
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-LU09
# 0.03613987106856808
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-MK20
# 0.03633522172299277
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-OT01
# 0.03653057237741746
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-OT02
# 0.036725923031842155
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-OT03
# 0.036921273686266846
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-OT04
# 0.03711662434069154
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-OT05
# 0.03731197499511623
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-RA02
# 0.03750732564954093
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-RA09
# 0.03770267630396562
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-SA20
# 0.03789802695839031
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-SF02
# 0.038093377612815005
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-SI15
# 0.0382887282672397
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-SJ02
# 0.03848407892166439
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-SO05
# 0.03867942957608908
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NM_GEOTH-VA01
# 0.03887478023051377
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NMISC-nm322419106204801
# 0.039070130884938464
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NMISC-nm322838106264401
# 0.039265481539363156
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NMISC-nm332143105594201
# 0.03946083219378785
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NMISC-nm332911106045101
# 0.03965618284821254
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NMISC-nm333446105424701
# 0.03985153350263723
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NMISC-nm351910106343101
# 0.040046884157061924
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NURE-OR10039
# 0.040242234811486616
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NURE-OR10145
# 0.04043758546591131
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: NURE-OR102740
# 0.040632936120336006
# .................................
#
# ...
#
# .................................
# -----------------------------
# SITE NAME: USGS-463530122510501
# 0.986716155499121
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-463635122495001
# 0.9869115061535456
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-463655119261201
# 0.9871068568079703
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-463706097355601
# 0.987302207462395
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-464633097130901
# 0.9874975581168197
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-464903119140901
# 0.9876929087712444
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-465006119321901
# 0.987888259425669
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-465050119355901
# 0.9880836100800938
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-465220096534501
# 0.9882789607345185
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-465314102470101
# 0.9884743113889431
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-465314102470102
# 0.9886696620433678
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-465342123465801
# 0.9888650126977926
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-465428119451701
# 0.9890603633522173
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-470404109223801
# 0.9892557140066419
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-470418119431401
# 0.9894510646610666
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-470518118523601
# 0.9896464153154914
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-470627119182501
# 0.989841765969916
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-470720119221001
# 0.9900371166243407
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-470745118225501
# 0.9902324672787653
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471104100584601
# 0.9904278179331901
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471130109564401
# 0.9906231685876148
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471202122343101
# 0.9908185192420395
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471318119373501
# 0.9910138698964641
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471403109354901
# 0.9912092205508889
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471527101464301
# 0.9914045712053136
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471540101464301
# 0.9915999218597382
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471606097300104
# 0.9917952725141629
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471620101053801
# 0.9919906231685877
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471638101081101
# 0.9921859738230123
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-471816122261301
# 0.992381324477437
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-472216102444601
# 0.9925766751318617
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-472453105350301
# 0.9927720257862864
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-472614098000003
# 0.9929673764407111
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-473056122173001
# 0.9931627270951358
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-473108100561601
# 0.9933580777495604
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-473452111183001
# 0.9935534284039852
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-473608103024301
# 0.9937487790584099
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-473945101504001
# 0.9939441297128345
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-474556118431101
# 0.9941394803672592
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-474720099532801
# 0.994334831021684
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-474720099532802
# 0.9945301816761086
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-474901119380801
# 0.9947255323305333
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-475601118561801
# 0.994920882984958
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-480534099012303
# 0.9951162336393827
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-480603122235501
# 0.9953115842938074
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-480804104534601
# 0.9955069349482321
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-481231122481601
# 0.9957022856026567
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-481440122401701
# 0.9958976362570815
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-481443122252801
# 0.9960929869115062
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-481507122394201
# 0.9962883375659308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-482537097231901
# 0.9964836882203555
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483306104114901
# 0.9966790388747803
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483345119330901
# 0.9968743895292049
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483435104104701
# 0.9970697401836296
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483518104101501
# 0.9972650908380543
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483543104081901
# 0.997460441492479
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484023098540103
# 0.9976557921469037
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484127104061701
# 0.9978511428013284
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484135104055601
# 0.998046493455753
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484150104053901
# 0.9982418441101778
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484151104042501
# 0.9984371947646025
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484205104052201
# 0.9986325454190271
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484214104050001
# 0.9988278960734518
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484217104042501
# 0.9990232467278766
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-485055122360402
# 0.9992185973823012
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: UT_GEOTH-SJ-018
# 0.9994139480367259
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: UT_GEOTH-SL-051
# 0.9996092986911506
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: UT_GEOTH-SL-052
# 0.9998046493455753
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: UT_GEOTH-TO-028
# 1.0
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................

# %%
df.to_csv('/Users/mhardika/Documents/AMO/GeoToolAll_Methods/Water Source Data/Brackish/brackish_sites_with_metrics_baseline_dwi_updated_costs_transport_updated_basis.csv')
