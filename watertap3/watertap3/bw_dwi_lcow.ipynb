# %% [markdown]
# This file is a copied from a previous brackish water analysis file to update the baseline LCOW to the deep will injection scenarion in the Big Spring Case study

# %%
import matplotlib.pyplot as plt
import pandas as pd
import haversine as hs
import geopandas as gp
from shapely.geometry import Point, Polygon
import numpy as np

from pyomo.environ import Var, Expression, NonNegativeReals, Block, ConcreteModel, Constraint, Objective, Param, maximize, SolverFactory,RangeSet
import pyomo.environ as pyo
from idaes.core import FlowsheetBlock
from pyomo.environ import Block, Expression, units as pyunits
import math
from watertap3.utils import watertap_setup, get_case_study, run_model 
from watertap3.utils import run_watertap3, run_model_no_print, run_and_return_model
from truck_pipe_cost_functions import truck_costing, pipe_costing

# %% [markdown]
# 1. Update deep well injection well depth to 2500 - DWI model updated to be a detailed model
# 2. Update to KBHDP treatment train
# 3. Minimum well yield - Updated to 0.02 m3/s
# 4. Well LCOW and antiscalant list to the table

# %%
case_study = 'kbhdp'
scenario = 'dwi'
desired_recovery = 1
ro_bounds = 'other'

m = watertap_setup(case_study=case_study, scenario=scenario)
m = get_case_study(m=m)
m = run_watertap3(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds)

m.fs.ro_first_stage.membrane_area.unfix()
m.fs.ro_second_stage.membrane_area.unfix()
m = run_and_return_model(m, objective=True,print_it=True)

print('LCOW:', m.fs.costing.LCOW.value())
# Out:
# Case Study = KBHDP
# Scenario = DWI
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MEDIA FILTRATION
# CARTRIDGE FILTRATION
# ANTI SCALANT ADDITION
# RO FIRST STAGE
# PASSTHROUGH
# LIME SOFTENING
# RO SECOND STAGE
# CAUSTIC SODA ADDITION
# CHLORINATION
# TREATED STORAGE
# DEEP WELL INJECTION
# MUNICIPAL DRINKING
# =======================================================================
#
#
# =========================START WT3 MODEL RUN==========================
# .................................
#
# Degrees of Freedom: 4
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 4
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = KBHDP
# Scenario = DWI
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MEDIA FILTRATION
# CARTRIDGE FILTRATION
# ANTI SCALANT ADDITION
# RO FIRST STAGE
# PASSTHROUGH
# LIME SOFTENING
# RO SECOND STAGE
# CAUSTIC SODA ADDITION
# CHLORINATION
# TREATED STORAGE
# DEEP WELL INJECTION
# MUNICIPAL DRINKING
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 4
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# KBHDP: DWI
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 0.49473
# Total Capital Investment ($MM): 122.923
# Total Annual Operating Costs ($MM/yr): 10.688
# Annual Fixed Operating Cost ($MM/yr): 1.632
# Annual Catalysts and Chemicals Cost ($MM/yr): 5.738
# Annual Electricity Costs ($MM/yr): 1.63
# Annual Other Variable Costs ($MM/yr): 1.688
# Treated water (m3/s): 1.198
# Total water recovery (%): 89.621
# Electricity intensity (kWh/m3): 0.792
# Electricity portion of LCOW (%): 8.723
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field:
# 	Total Capital Investment ($MM): 12.50535
# 	Annual O&M ($MM/yr): 0.1659
# 	Annual Fixed O&M ($MM/yr): 0.1659
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02593
# 	Flow In (m3/s): 1.33628
# 	Flow Out (m3/s): 1.33614
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Media Filtration:
# 	Total Capital Investment ($MM): 7.92421
# 	Annual O&M ($MM/yr): 0.10573
# 	Annual Fixed O&M ($MM/yr): 0.10552
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00021
# 	Electricity Intensity (kWh/m3): 0.00015
# 	Unit LCOW ($/m3): 0.01645
# 	Flow In (m3/s): 0.81104
# 	Flow Out (m3/s): 0.81096
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# Cartridge Filtration:
# 	Total Capital Investment ($MM): 4.58167
# 	Annual O&M ($MM/yr): 0.06129
# 	Annual Fixed O&M ($MM/yr): 0.06101
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00028
# 	Electricity Intensity (kWh/m3): 0.0002
# 	Unit LCOW ($/m3): 0.00951
# 	Flow In (m3/s): 0.81096
# 	Flow Out (m3/s): 0.81088
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# Anti Scalant Addition:
# 	Total Capital Investment ($MM): 0.12418
# 	Annual O&M ($MM/yr): 0.6495
# 	Annual Fixed O&M ($MM/yr): 0.00165
# 	Annual Chemical Cost ($MM/yr): 0.64784
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01741
# 	Flow In (m3/s): 0.81088
# 	Flow Out (m3/s): 0.8108
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# RO First Stage:
# 	Total Capital Investment ($MM): 35.37552
# 	Annual O&M ($MM/yr): 2.58062
# 	Annual Fixed O&M ($MM/yr): 0.47107
# 	Annual Chemical Cost ($MM/yr): 0.33643
# 	Annual Electricity Cost ($MM/yr): 0.62945
# 	Electricity Intensity (kWh/m3): 0.45139
# 	Unit LCOW ($/m3): 0.12926
# 	Flow In (m3/s): 0.8108
# 	Flow Out (m3/s): 0.51078
# 	Flow Waste (m3/s): 0.30148
#
# 	.....RO First Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 14.0 bar = 203 psi
# 	Area = 152489 m2 ---> 4103 membrane modules
# 	Flux = 12.1 LMH
# 	TDS in = 2500.9 mg/L
# 	TDS out = 47.782 mg/L
# 	TDS waste = 6644.989 mg/L
# 	Flow in = 0.8108 m3/s = 18.50599 MGD = 12851.38 gpm
# 	Flow out = 0.51078 m3/s = 11.65827 MGD = 8096.02 gpm
# 	Flow waste = 0.30148 m3/s = 6.88106 MGD = 4778.52 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 63.0%
#
# Passthrough:
# 	Total Capital Investment ($MM): 0.0
# 	Annual O&M ($MM/yr): 0.0
# 	Annual Fixed O&M ($MM/yr): 0.0
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0
# 	Flow In (m3/s): 0.30148
# 	Flow Out (m3/s): 0.30145
# 	Flow Waste (m3/s): 3e-05
# 	Water Recovery (%): 99.99
#
# Lime Softening:
# 	Total Capital Investment ($MM): 12.22161
# 	Annual O&M ($MM/yr): 4.4431
# 	Annual Fixed O&M ($MM/yr): 0.16214
# 	Annual Chemical Cost ($MM/yr): 4.28083
# 	Annual Electricity Cost ($MM/yr): 0.00013
# 	Electricity Intensity (kWh/m3): 0.00025
# 	Unit LCOW ($/m3): 0.1387
# 	Flow In (m3/s): 0.30145
# 	Flow Out (m3/s): 0.30115
# 	Flow Waste (m3/s): 0.0003
# 	Water Recovery (%): 99.9
#
# RO Second Stage:
# 	Total Capital Investment ($MM): 16.62523
# 	Annual O&M ($MM/yr): 1.19275
# 	Annual Fixed O&M ($MM/yr): 0.22138
# 	Annual Chemical Cost ($MM/yr): 0.15811
# 	Annual Electricity Cost ($MM/yr): 0.26866
# 	Electricity Intensity (kWh/m3): 0.5187
# 	Unit LCOW ($/m3): 0.06022
# 	Flow In (m3/s): 0.30115
# 	Flow Out (m3/s): 0.16218
# 	Flow Waste (m3/s): 0.13943
#
# 	.....RO Second Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 15.94 bar = 231 psi
# 	Area = 72614 m2 ---> 1954 membrane modules
# 	Flux = 8.0 LMH
# 	TDS in = 6652.173 mg/L
# 	TDS out = 163.212 mg/L
# 	TDS waste = 14178.159 mg/L
# 	Flow in = 0.30115 m3/s = 6.87349 MGD = 4773.26 gpm
# 	Flow out = 0.16218 m3/s = 3.7017 MGD = 2570.63 gpm
# 	Flow waste = 0.13943 m3/s = 3.18232 MGD = 2209.95 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 53.900000000000006%
#
# Caustic Soda Addition:
# 	Total Capital Investment ($MM): 1.44578
# 	Annual O&M ($MM/yr): 0.20027
# 	Annual Fixed O&M ($MM/yr): 0.01925
# 	Annual Chemical Cost ($MM/yr): 0.18101
# 	Annual Electricity Cost ($MM/yr): 1e-05
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.00779
# 	Flow In (m3/s): 1.19807
# 	Flow Out (m3/s): 1.19795
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# Chlorination:
# 	Total Capital Investment ($MM): 7.97712
# 	Annual O&M ($MM/yr): 0.24011
# 	Annual Fixed O&M ($MM/yr): 0.10622
# 	Annual Chemical Cost ($MM/yr): 0.13379
# 	Annual Electricity Cost ($MM/yr): 0.0001
# 	Electricity Intensity (kWh/m3): 5e-05
# 	Unit LCOW ($/m3): 0.0201
# 	Flow In (m3/s): 1.19795
# 	Flow Out (m3/s): 1.19783
# 	Flow Waste (m3/s): 0.00012
# 	Chlorine dose (mg/L): 9.5
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 14.30774
# 	Annual O&M ($MM/yr): 0.18807
# 	Annual Fixed O&M ($MM/yr): 0.18807
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02962
# 	Flow In (m3/s): 1.19783
# 	Flow Out (m3/s): 1.19771
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 7.30929
# 	Annual O&M ($MM/yr): 0.19441
# 	Annual Fixed O&M ($MM/yr): 0.09619
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.09822
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.01774
# 	Flow In (m3/s): 0.13943
# 	Flow Out (m3/s): 0.13941
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 2.52574
# 	Annual O&M ($MM/yr): 0.66631
# 	Annual Fixed O&M ($MM/yr): 0.03351
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.6328
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.02199
# 	Flow In (m3/s): 1.19771
# 	Flow Out (m3/s): 1.19759
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# KBHDP: DWI
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 0.46009
# Total Capital Investment ($MM): 121.679
# Total Annual Operating Costs ($MM/yr): 9.035
# Annual Fixed Operating Cost ($MM/yr): 1.616
# Annual Catalysts and Chemicals Cost ($MM/yr): 4.06
# Annual Electricity Costs ($MM/yr): 1.528
# Annual Other Variable Costs ($MM/yr): 1.831
# Treated water (m3/s): 1.168
# Total water recovery (%): 87.424
# Electricity intensity (kWh/m3): 0.761
# Electricity portion of LCOW (%): 9.018
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field:
# 	Total Capital Investment ($MM): 12.50535
# 	Annual O&M ($MM/yr): 0.1659
# 	Annual Fixed O&M ($MM/yr): 0.1659
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02658
# 	Flow In (m3/s): 1.33628
# 	Flow Out (m3/s): 1.33614
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Media Filtration:
# 	Total Capital Investment ($MM): 7.92421
# 	Annual O&M ($MM/yr): 0.10573
# 	Annual Fixed O&M ($MM/yr): 0.10552
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00021
# 	Electricity Intensity (kWh/m3): 0.00015
# 	Unit LCOW ($/m3): 0.01686
# 	Flow In (m3/s): 0.81104
# 	Flow Out (m3/s): 0.81096
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# Cartridge Filtration:
# 	Total Capital Investment ($MM): 4.58167
# 	Annual O&M ($MM/yr): 0.06129
# 	Annual Fixed O&M ($MM/yr): 0.06101
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00028
# 	Electricity Intensity (kWh/m3): 0.0002
# 	Unit LCOW ($/m3): 0.00975
# 	Flow In (m3/s): 0.81096
# 	Flow Out (m3/s): 0.81088
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# Anti Scalant Addition:
# 	Total Capital Investment ($MM): 0.12418
# 	Annual O&M ($MM/yr): 0.6495
# 	Annual Fixed O&M ($MM/yr): 0.00165
# 	Annual Chemical Cost ($MM/yr): 0.64784
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01785
# 	Flow In (m3/s): 0.81088
# 	Flow Out (m3/s): 0.8108
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# RO First Stage:
# 	Total Capital Investment ($MM): 52.14175
# 	Annual O&M ($MM/yr): 3.60127
# 	Annual Fixed O&M ($MM/yr): 0.69433
# 	Annual Chemical Cost ($MM/yr): 0.49588
# 	Annual Electricity Cost ($MM/yr): 0.62945
# 	Electricity Intensity (kWh/m3): 0.45139
# 	Unit LCOW ($/m3): 0.18982
# 	Flow In (m3/s): 0.8108
# 	Flow Out (m3/s): 0.63066
# 	Flow Waste (m3/s): 0.18194
#
# 	.....RO First Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 14.0 bar = 203 psi
# 	Area = 237548 m2 ---> 6392 membrane modules
# 	Flux = 9.6 LMH
# 	TDS in = 2500.9 mg/L
# 	TDS out = 87.94 mg/L
# 	TDS waste = 10840.101 mg/L
# 	Flow in = 0.8108 m3/s = 18.50599 MGD = 12851.38 gpm
# 	Flow out = 0.63066 m3/s = 14.39438 MGD = 9996.09 gpm
# 	Flow waste = 0.18194 m3/s = 4.15271 MGD = 2883.83 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 77.8%
#
# Passthrough:
# 	Total Capital Investment ($MM): 0.0
# 	Annual O&M ($MM/yr): 0.0
# 	Annual Fixed O&M ($MM/yr): 0.0
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0
# 	Flow In (m3/s): 0.18194
# 	Flow Out (m3/s): 0.18192
# 	Flow Waste (m3/s): 2e-05
# 	Water Recovery (%): 99.99
#
# Lime Softening:
# 	Total Capital Investment ($MM): 8.45066
# 	Annual O&M ($MM/yr): 2.69566
# 	Annual Fixed O&M ($MM/yr): 0.11211
# 	Annual Chemical Cost ($MM/yr): 2.58347
# 	Annual Electricity Cost ($MM/yr): 8e-05
# 	Electricity Intensity (kWh/m3): 0.00025
# 	Unit LCOW ($/m3): 0.08809
# 	Flow In (m3/s): 0.18192
# 	Flow Out (m3/s): 0.18174
# 	Flow Waste (m3/s): 0.00018
# 	Water Recovery (%): 99.9
#
# RO Second Stage:
# 	Total Capital Investment ($MM): 2.65973
# 	Annual O&M ($MM/yr): 0.27241
# 	Annual Fixed O&M ($MM/yr): 0.03542
# 	Annual Chemical Cost ($MM/yr): 0.02529
# 	Annual Electricity Cost ($MM/yr): 0.16213
# 	Electricity Intensity (kWh/m3): 0.5187
# 	Unit LCOW ($/m3): 0.01209
# 	Flow In (m3/s): 0.18174
# 	Flow Out (m3/s): 0.01293
# 	Flow Waste (m3/s): 0.16885
#
# 	.....RO Second Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 15.94 bar = 231 psi
# 	Area = 6609 m2 ---> 178 membrane modules
# 	Flux = 7.0 LMH
# 	TDS in = 10851.82 mg/L
# 	TDS out = 201.416 mg/L
# 	TDS waste = 11665.008 mg/L
# 	Flow in = 0.18174 m3/s = 4.14814 MGD = 2880.66 gpm
# 	Flow out = 0.01293 m3/s = 0.29511 MGD = 204.94 gpm
# 	Flow waste = 0.16885 m3/s = 3.85387 MGD = 2676.3 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 7.1%
#
# Caustic Soda Addition:
# 	Total Capital Investment ($MM): 1.42371
# 	Annual O&M ($MM/yr): 0.19554
# 	Annual Fixed O&M ($MM/yr): 0.01896
# 	Annual Chemical Cost ($MM/yr): 0.17658
# 	Annual Electricity Cost ($MM/yr): 1e-05
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.00782
# 	Flow In (m3/s): 1.16869
# 	Flow Out (m3/s): 1.16857
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# Chlorination:
# 	Total Capital Investment ($MM): 7.91498
# 	Annual O&M ($MM/yr): 0.236
# 	Annual Fixed O&M ($MM/yr): 0.10539
# 	Annual Chemical Cost ($MM/yr): 0.13051
# 	Annual Electricity Cost ($MM/yr): 0.0001
# 	Electricity Intensity (kWh/m3): 5e-05
# 	Unit LCOW ($/m3): 0.02038
# 	Flow In (m3/s): 1.16857
# 	Flow Out (m3/s): 1.16846
# 	Flow Waste (m3/s): 0.00012
# 	Chlorine dose (mg/L): 9.5
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 14.05395
# 	Annual O&M ($MM/yr): 0.18473
# 	Annual Fixed O&M ($MM/yr): 0.18473
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02983
# 	Flow In (m3/s): 1.16846
# 	Flow Out (m3/s): 1.16834
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 7.42653
# 	Annual O&M ($MM/yr): 0.21668
# 	Annual Fixed O&M ($MM/yr): 0.09773
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.11895
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.01899
# 	Flow In (m3/s): 0.16885
# 	Flow Out (m3/s): 0.16883
# 	Flow Waste (m3/s): 2e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 2.47204
# 	Annual O&M ($MM/yr): 0.65008
# 	Annual Fixed O&M ($MM/yr): 0.0328
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.61728
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.02201
# 	Flow In (m3/s): 1.16834
# 	Flow Out (m3/s): 1.16822
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
# LCOW: 0.46008896301817603

# %%
# Read in brackish database. It is filtered for the correct columns. 
df = pd.read_csv('/Users/mhardika/Documents/AMO/GeoToolAll_Methods/Water Source Data/Brackish/USGS_brackish_filtered.csv', index_col='unique_site_ID')

# Convert USGS unit to our units: gpm to m3/s, 
df.well_yield = df.well_yield * 6.30902e-5 #gpm to m3/s
df.TDS_mgL = df.TDS_mgL / 1000 #mg/L to kg/m3
df = df.rename(columns={'TDS_mgL': 'TDS_kgm3'})

path = 'C:/Users/mhardika/Documents/watertap3/WaterTAP3/watertap3/watertap3/data'

# Add state look up for electricity prices and add elec price column
state_abbv_df = pd.read_csv(path + '/state_abbv.csv', index_col='abbv')
elec_price_df = pd.read_csv(path + '/industrial_electricity_costs_2023.csv', index_col='location')
df['state'] = df.state_alpha.map(state_abbv_df.us_state)
df['elec_price'] = df.state.map(elec_price_df.cost)


# filter for well of interest in the US
df = df[df.well_yield >= 0.02] # Filter changed to 0.02 m3/s because after that pipe transport cost is > $1
df = df[df.TDS_kgm3 >= 0.5]
df = df[df.Latitude >= 22]
df = df[df.Longitude >= -150]
df = df[df.TDS_kgm3 <= 17] # Updated because treating anything higher results in very high pressures in second stage RO

# Loop through brackish sites and calculate+save LCOW, capital, O&M, energy intensity, and recovery in a df.
capital = []
recovery = []
onm = []
lcow = []
pipe_cost = []
elec_int = []
tds_out = []
flow_in_list = []
tds_in_list = []
well_field_annual_op_main_cost_list = []
well_field_total_cap_inv_list = []
well_field_lcow_list = []
i = 0


for site in df.index:
    print('-----------------------------')
    print('SITE NAME:', site)
    i = i + 1
    print(i/len(df.index))

    try:
        # See if watertap3 solves without rerunning baseline case
        m.fs.ro_first_stage.membrane_area.unfix()
        m.fs.ro_second_stage.membrane_area.unfix()       
        
        m.fs.kbhdp_brackish_ave.flow_vol_in.fix(df.loc[site].well_yield)
        m.fs.kbhdp_brackish_ave.conc_mass_in[0, 'tds'].fix(df.loc[site].TDS_kgm3)
        m.fs.well_field.lift_height.fix(df.loc[site].well_depth_ft)
        
        m.fs.costing_param.electricity_price = df.loc[site].elec_price

        m = run_and_return_model(m, objective=True)
    
    except:
        m = watertap_setup(case_study=case_study, scenario=scenario)
        m = get_case_study(m=m)
        m = run_watertap3(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds)

        m.fs.ro_first_stage.membrane_area.unfix()
        m.fs.ro_second_stage.membrane_area.unfix()
        m.fs.ro_first_stage.feed.pressure.unfix()

        m.fs.kbhdp_brackish_ave.flow_vol_in.fix(df.loc[site].well_yield)
        m.fs.kbhdp_brackish_ave.conc_mass_in[0, 'tds'].fix(df.loc[site].TDS_kgm3)
        m.fs.well_field.lift_height.fix(df.loc[site].well_depth_ft)
        
        m.fs.costing_param.electricity_price = df.loc[site].elec_price
        m = run_and_return_model(m, objective=True,print_it=True)


    # Basis is recalculated to be on treated volume basis instead of brine volume
    temp = pipe_costing(m.fs.deep_well_injection.flow_vol_in[0].value*3600*24,16.0934,pumping_velocity = 1.5)*(1-m.fs.costing.system_recovery())/m.fs.costing.system_recovery()
    
    flow_in_list.append(df.loc[site].well_yield)
    capital.append(m.fs.costing.capital_investment_total())
    recovery.append(m.fs.costing.system_recovery()*100)
    onm.append(m.fs.costing.operating_cost_annual())
    pipe_cost.append(temp)
    lcow.append(m.fs.costing.LCOW())
    elec_int.append(m.fs.costing.electricity_intensity())
    tds_out.append(m.fs.municipal_drinking.conc_mass_in[0, 'tds']())
    tds_in_list.append(df.loc[site].TDS_kgm3)
    well_field_annual_op_main_cost_list.append(m.fs.well_field.costing.annual_op_main_cost())
    well_field_total_cap_inv_list.append(m.fs.well_field.costing.total_cap_investment())
    well_field_lcow_list.append(m.fs.well_field.LCOW())
    
df['treatment_lcow'] = lcow
df['pipe_lcow'] = pipe_cost
df['lcow'] = df['treatment_lcow'] + df['pipe_lcow'] # Total LCOW which includes treatment and brine disposal costs
df['recovery'] = recovery
df['capital'] = capital
df['onm'] = onm
df['elec_int'] = elec_int
df['tds_out'] = tds_out
df['well_field_o&m'] = well_field_annual_op_main_cost_list
df['well_field_cap_inv'] = well_field_total_cap_inv_list
df['well_field_lcow'] = well_field_lcow_list
# Out:
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# Case Study = KBHDP
# Scenario = DWI
#
#
# =========================ADDING UNIT PROCESSES=========================
# WELL FIELD
# MEDIA FILTRATION
# CARTRIDGE FILTRATION
# ANTI SCALANT ADDITION
# RO FIRST STAGE
# PASSTHROUGH
# LIME SOFTENING
# RO SECOND STAGE
# CAUSTIC SODA ADDITION
# CHLORINATION
# TREATED STORAGE
# DEEP WELL INJECTION
# MUNICIPAL DRINKING
# =======================================================================
#
# .................................
#
# Degrees of Freedom: 4
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# .................................
#
# Degrees of Freedom: 0
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# KBHDP: DWI
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 0.49473
# Total Capital Investment ($MM): 122.923
# Total Annual Operating Costs ($MM/yr): 10.688
# Annual Fixed Operating Cost ($MM/yr): 1.632
# Annual Catalysts and Chemicals Cost ($MM/yr): 5.738
# Annual Electricity Costs ($MM/yr): 1.63
# Annual Other Variable Costs ($MM/yr): 1.688
# Treated water (m3/s): 1.198
# Total water recovery (%): 89.621
# Electricity intensity (kWh/m3): 0.792
# Electricity portion of LCOW (%): 8.723
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field:
# 	Total Capital Investment ($MM): 12.50535
# 	Annual O&M ($MM/yr): 0.1659
# 	Annual Fixed O&M ($MM/yr): 0.1659
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02593
# 	Flow In (m3/s): 1.33628
# 	Flow Out (m3/s): 1.33614
# 	Flow Waste (m3/s): 0.00013
# 	Water Recovery (%): 99.99
#
# Media Filtration:
# 	Total Capital Investment ($MM): 7.92421
# 	Annual O&M ($MM/yr): 0.10573
# 	Annual Fixed O&M ($MM/yr): 0.10552
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00021
# 	Electricity Intensity (kWh/m3): 0.00015
# 	Unit LCOW ($/m3): 0.01645
# 	Flow In (m3/s): 0.81104
# 	Flow Out (m3/s): 0.81096
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# Cartridge Filtration:
# 	Total Capital Investment ($MM): 4.58167
# 	Annual O&M ($MM/yr): 0.06129
# 	Annual Fixed O&M ($MM/yr): 0.06101
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00028
# 	Electricity Intensity (kWh/m3): 0.0002
# 	Unit LCOW ($/m3): 0.00951
# 	Flow In (m3/s): 0.81096
# 	Flow Out (m3/s): 0.81088
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# Anti Scalant Addition:
# 	Total Capital Investment ($MM): 0.12418
# 	Annual O&M ($MM/yr): 0.6495
# 	Annual Fixed O&M ($MM/yr): 0.00165
# 	Annual Chemical Cost ($MM/yr): 0.64784
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01741
# 	Flow In (m3/s): 0.81088
# 	Flow Out (m3/s): 0.8108
# 	Flow Waste (m3/s): 8e-05
# 	Water Recovery (%): 99.99
#
# RO First Stage:
# 	Total Capital Investment ($MM): 35.37552
# 	Annual O&M ($MM/yr): 2.58062
# 	Annual Fixed O&M ($MM/yr): 0.47107
# 	Annual Chemical Cost ($MM/yr): 0.33643
# 	Annual Electricity Cost ($MM/yr): 0.62945
# 	Electricity Intensity (kWh/m3): 0.45139
# 	Unit LCOW ($/m3): 0.12926
# 	Flow In (m3/s): 0.8108
# 	Flow Out (m3/s): 0.51078
# 	Flow Waste (m3/s): 0.30148
#
# 	.....RO First Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 14.0 bar = 203 psi
# 	Area = 152489 m2 ---> 4103 membrane modules
# 	Flux = 12.1 LMH
# 	TDS in = 2500.9 mg/L
# 	TDS out = 47.782 mg/L
# 	TDS waste = 6644.989 mg/L
# 	Flow in = 0.8108 m3/s = 18.50599 MGD = 12851.38 gpm
# 	Flow out = 0.51078 m3/s = 11.65827 MGD = 8096.02 gpm
# 	Flow waste = 0.30148 m3/s = 6.88106 MGD = 4778.52 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 63.0%
#
# Passthrough:
# 	Total Capital Investment ($MM): 0.0
# 	Annual O&M ($MM/yr): 0.0
# 	Annual Fixed O&M ($MM/yr): 0.0
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0
# 	Flow In (m3/s): 0.30148
# 	Flow Out (m3/s): 0.30145
# 	Flow Waste (m3/s): 3e-05
# 	Water Recovery (%): 99.99
#
# Lime Softening:
# 	Total Capital Investment ($MM): 12.22161
# 	Annual O&M ($MM/yr): 4.4431
# 	Annual Fixed O&M ($MM/yr): 0.16214
# 	Annual Chemical Cost ($MM/yr): 4.28083
# 	Annual Electricity Cost ($MM/yr): 0.00013
# 	Electricity Intensity (kWh/m3): 0.00025
# 	Unit LCOW ($/m3): 0.1387
# 	Flow In (m3/s): 0.30145
# 	Flow Out (m3/s): 0.30115
# 	Flow Waste (m3/s): 0.0003
# 	Water Recovery (%): 99.9
#
# RO Second Stage:
# 	Total Capital Investment ($MM): 16.62523
# 	Annual O&M ($MM/yr): 1.19275
# 	Annual Fixed O&M ($MM/yr): 0.22138
# 	Annual Chemical Cost ($MM/yr): 0.15811
# 	Annual Electricity Cost ($MM/yr): 0.26866
# 	Electricity Intensity (kWh/m3): 0.5187
# 	Unit LCOW ($/m3): 0.06022
# 	Flow In (m3/s): 0.30115
# 	Flow Out (m3/s): 0.16218
# 	Flow Waste (m3/s): 0.13943
#
# 	.....RO Second Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 15.94 bar = 231 psi
# 	Area = 72614 m2 ---> 1954 membrane modules
# 	Flux = 8.0 LMH
# 	TDS in = 6652.173 mg/L
# 	TDS out = 163.212 mg/L
# 	TDS waste = 14178.159 mg/L
# 	Flow in = 0.30115 m3/s = 6.87349 MGD = 4773.26 gpm
# 	Flow out = 0.16218 m3/s = 3.7017 MGD = 2570.63 gpm
# 	Flow waste = 0.13943 m3/s = 3.18232 MGD = 2209.95 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 53.900000000000006%
#
# Caustic Soda Addition:
# 	Total Capital Investment ($MM): 1.44578
# 	Annual O&M ($MM/yr): 0.20027
# 	Annual Fixed O&M ($MM/yr): 0.01925
# 	Annual Chemical Cost ($MM/yr): 0.18101
# 	Annual Electricity Cost ($MM/yr): 1e-05
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.00779
# 	Flow In (m3/s): 1.19807
# 	Flow Out (m3/s): 1.19795
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# Chlorination:
# 	Total Capital Investment ($MM): 7.97712
# 	Annual O&M ($MM/yr): 0.24011
# 	Annual Fixed O&M ($MM/yr): 0.10622
# 	Annual Chemical Cost ($MM/yr): 0.13379
# 	Annual Electricity Cost ($MM/yr): 0.0001
# 	Electricity Intensity (kWh/m3): 5e-05
# 	Unit LCOW ($/m3): 0.0201
# 	Flow In (m3/s): 1.19795
# 	Flow Out (m3/s): 1.19783
# 	Flow Waste (m3/s): 0.00012
# 	Chlorine dose (mg/L): 9.5
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 14.30774
# 	Annual O&M ($MM/yr): 0.18807
# 	Annual Fixed O&M ($MM/yr): 0.18807
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02962
# 	Flow In (m3/s): 1.19783
# 	Flow Out (m3/s): 1.19771
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 7.30929
# 	Annual O&M ($MM/yr): 0.19441
# 	Annual Fixed O&M ($MM/yr): 0.09619
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.09822
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.01774
# 	Flow In (m3/s): 0.13943
# 	Flow Out (m3/s): 0.13941
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 2.52574
# 	Annual O&M ($MM/yr): 0.66631
# 	Annual Fixed O&M ($MM/yr): 0.03351
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.6328
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.02199
# 	Flow In (m3/s): 1.19771
# 	Flow Out (m3/s): 1.19759
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# KBHDP: DWI
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 0.91699
# Total Capital Investment ($MM): 15.779
# Total Annual Operating Costs ($MM/yr): 0.498
# Annual Fixed Operating Cost ($MM/yr): 0.209
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.115
# Annual Electricity Costs ($MM/yr): 0.146
# Annual Other Variable Costs ($MM/yr): 0.028
# Treated water (m3/s): 0.053
# Total water recovery (%): 92.564
# Electricity intensity (kWh/m3): 1.039
# Electricity portion of LCOW (%): 9.598
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field:
# 	Total Capital Investment ($MM): 0.68694
# 	Annual O&M ($MM/yr): 0.01519
# 	Annual Fixed O&M ($MM/yr): 0.00911
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00608
# 	Electricity Intensity (kWh/m3): 0.03994
# 	Unit LCOW ($/m3): 0.03602
# 	Flow In (m3/s): 0.05696
# 	Flow Out (m3/s): 0.05695
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Media Filtration:
# 	Total Capital Investment ($MM): 1.23701
# 	Annual O&M ($MM/yr): 0.01649
# 	Annual Fixed O&M ($MM/yr): 0.01647
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 1e-05
# 	Electricity Intensity (kWh/m3): 0.00015
# 	Unit LCOW ($/m3): 0.05832
# 	Flow In (m3/s): 0.03457
# 	Flow Out (m3/s): 0.03457
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Cartridge Filtration:
# 	Total Capital Investment ($MM): 0.72065
# 	Annual O&M ($MM/yr): 0.00961
# 	Annual Fixed O&M ($MM/yr): 0.0096
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 2e-05
# 	Electricity Intensity (kWh/m3): 0.0002
# 	Unit LCOW ($/m3): 0.03398
# 	Flow In (m3/s): 0.03457
# 	Flow Out (m3/s): 0.03456
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Anti Scalant Addition:
# 	Total Capital Investment ($MM): 0.01767
# 	Annual O&M ($MM/yr): 0.02785
# 	Annual Fixed O&M ($MM/yr): 0.00024
# 	Annual Chemical Cost ($MM/yr): 0.02761
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01744
# 	Flow In (m3/s): 0.03456
# 	Flow Out (m3/s): 0.03456
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# RO First Stage:
# 	Total Capital Investment ($MM): 1.23093
# 	Annual O&M ($MM/yr): 0.14248
# 	Annual Fixed O&M ($MM/yr): 0.01639
# 	Annual Chemical Cost ($MM/yr): 0.01171
# 	Annual Electricity Cost ($MM/yr): 0.08628
# 	Electricity Intensity (kWh/m3): 0.93407
# 	Unit LCOW ($/m3): 0.13386
# 	Flow In (m3/s): 0.03456
# 	Flow Out (m3/s): 0.03035
# 	Flow Waste (m3/s): 0.0043
#
# 	.....RO First Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 27.9 bar = 405 psi
# 	Area = 3746 m2 ---> 101 membrane modules
# 	Flux = 29.2 LMH
# 	TDS in = 1780.641 mg/L
# 	TDS out = 34.272 mg/L
# 	TDS waste = 14084.994 mg/L
# 	Flow in = 0.03456 m3/s = 0.78878 MGD = 547.77 gpm
# 	Flow out = 0.03035 m3/s = 0.69273 MGD = 481.06 gpm
# 	Flow waste = 0.0043 m3/s = 0.09803 MGD = 68.08 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 87.8%
#
# Passthrough:
# 	Total Capital Investment ($MM): 0.0
# 	Annual O&M ($MM/yr): 0.0
# 	Annual Fixed O&M ($MM/yr): 0.0
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0
# 	Flow In (m3/s): 0.0043
# 	Flow Out (m3/s): 0.00429
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Lime Softening:
# 	Total Capital Investment ($MM): 0.54731
# 	Annual O&M ($MM/yr): 0.06825
# 	Annual Fixed O&M ($MM/yr): 0.00726
# 	Annual Chemical Cost ($MM/yr): 0.06099
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.00025
# 	Unit LCOW ($/m3): 0.06247
# 	Flow In (m3/s): 0.00429
# 	Flow Out (m3/s): 0.00429
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.9
#
# RO Second Stage:
# 	Total Capital Investment ($MM): 0.07342
# 	Annual O&M ($MM/yr): 0.0077
# 	Annual Fixed O&M ($MM/yr): 0.00098
# 	Annual Chemical Cost ($MM/yr): 0.0007
# 	Annual Electricity Cost ($MM/yr): 0.00595
# 	Electricity Intensity (kWh/m3): 0.5187
# 	Unit LCOW ($/m3): 0.0075
# 	Flow In (m3/s): 0.00429
# 	Flow Out (m3/s): 1e-05
# 	Flow Waste (m3/s): 0.00428
#
# 	.....RO Second Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 15.94 bar = 231 psi
# 	Area = 10 m2 ---> 0 membrane modules
# 	Flux = 3.6 LMH
# 	TDS in = 14100.221 mg/L
# 	TDS out = 491.541 mg/L
# 	TDS waste = 14132.085 mg/L
# 	Flow in = 0.00429 m3/s = 0.09793 MGD = 68.0 gpm
# 	Flow out = 1e-05 m3/s = 0.00023 MGD = 0.16 gpm
# 	Flow waste = 0.00428 m3/s = 0.0977 MGD = 67.85 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 0.2%
#
# Caustic Soda Addition:
# 	Total Capital Investment ($MM): 0.20886
# 	Annual O&M ($MM/yr): 0.01075
# 	Annual Fixed O&M ($MM/yr): 0.00278
# 	Annual Chemical Cost ($MM/yr): 0.00797
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01464
# 	Flow In (m3/s): 0.05274
# 	Flow Out (m3/s): 0.05274
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Chlorination:
# 	Total Capital Investment ($MM): 2.98273
# 	Annual O&M ($MM/yr): 0.04561
# 	Annual Fixed O&M ($MM/yr): 0.03972
# 	Annual Chemical Cost ($MM/yr): 0.00589
# 	Annual Electricity Cost ($MM/yr): 1e-05
# 	Electricity Intensity (kWh/m3): 5e-05
# 	Unit LCOW ($/m3): 0.14414
# 	Flow In (m3/s): 0.05274
# 	Flow Out (m3/s): 0.05273
# 	Flow Waste (m3/s): 1e-05
# 	Chlorine dose (mg/L): 9.5
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 1.50577
# 	Annual O&M ($MM/yr): 0.01979
# 	Annual Fixed O&M ($MM/yr): 0.01979
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.07082
# 	Flow In (m3/s): 0.05273
# 	Flow Out (m3/s): 0.05273
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 6.39843
# 	Annual O&M ($MM/yr): 0.08889
# 	Annual Fixed O&M ($MM/yr): 0.0842
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00469
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.30381
# 	Flow In (m3/s): 0.00428
# 	Flow Out (m3/s): 0.00428
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.16913
# 	Annual O&M ($MM/yr): 0.04554
# 	Annual Fixed O&M ($MM/yr): 0.00224
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.04329
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.03401
# 	Flow In (m3/s): 0.05273
# 	Flow Out (m3/s): 0.05272
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
# -----------------------------
# SITE NAME: FETH-402238N1043713.1
# 0.013776722090261283
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-402800N1042900.1
# 0.014014251781472684
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-404844N1025311.1
# 0.014251781472684086
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-405430N0983700.1
# 0.014489311163895487
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-405800N0902130.1
# 0.014726840855106888
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-410315N1020520.1
# 0.01496437054631829
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH-412800N0915000.1
# 0.015201900237529691
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: FETH
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# ...
# 	Flow Out (m3/s): 0.30115
# 	Flow Waste (m3/s): 0.0003
# 	Water Recovery (%): 99.9
#
# RO Second Stage:
# 	Total Capital Investment ($MM): 16.62523
# 	Annual O&M ($MM/yr): 1.19275
# 	Annual Fixed O&M ($MM/yr): 0.22138
# 	Annual Chemical Cost ($MM/yr): 0.15811
# 	Annual Electricity Cost ($MM/yr): 0.26866
# 	Electricity Intensity (kWh/m3): 0.5187
# 	Unit LCOW ($/m3): 0.06022
# 	Flow In (m3/s): 0.30115
# 	Flow Out (m3/s): 0.16218
# 	Flow Waste (m3/s): 0.13943
#
# 	.....RO Second Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 15.94 bar = 231 psi
# 	Area = 72614 m2 ---> 1954 membrane modules
# 	Flux = 8.0 LMH
# 	TDS in = 6652.173 mg/L
# 	TDS out = 163.212 mg/L
# 	TDS waste = 14178.159 mg/L
# 	Flow in = 0.30115 m3/s = 6.87349 MGD = 4773.26 gpm
# 	Flow out = 0.16218 m3/s = 3.7017 MGD = 2570.63 gpm
# 	Flow waste = 0.13943 m3/s = 3.18232 MGD = 2209.95 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 53.900000000000006%
#
# Caustic Soda Addition:
# 	Total Capital Investment ($MM): 1.44578
# 	Annual O&M ($MM/yr): 0.20027
# 	Annual Fixed O&M ($MM/yr): 0.01925
# 	Annual Chemical Cost ($MM/yr): 0.18101
# 	Annual Electricity Cost ($MM/yr): 1e-05
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.00779
# 	Flow In (m3/s): 1.19807
# 	Flow Out (m3/s): 1.19795
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# Chlorination:
# 	Total Capital Investment ($MM): 7.97712
# 	Annual O&M ($MM/yr): 0.24011
# 	Annual Fixed O&M ($MM/yr): 0.10622
# 	Annual Chemical Cost ($MM/yr): 0.13379
# 	Annual Electricity Cost ($MM/yr): 0.0001
# 	Electricity Intensity (kWh/m3): 5e-05
# 	Unit LCOW ($/m3): 0.0201
# 	Flow In (m3/s): 1.19795
# 	Flow Out (m3/s): 1.19783
# 	Flow Waste (m3/s): 0.00012
# 	Chlorine dose (mg/L): 9.5
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 14.30774
# 	Annual O&M ($MM/yr): 0.18807
# 	Annual Fixed O&M ($MM/yr): 0.18807
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.02962
# 	Flow In (m3/s): 1.19783
# 	Flow Out (m3/s): 1.19771
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 7.30929
# 	Annual O&M ($MM/yr): 0.19441
# 	Annual Fixed O&M ($MM/yr): 0.09619
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.09822
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.01774
# 	Flow In (m3/s): 0.13943
# 	Flow Out (m3/s): 0.13941
# 	Flow Waste (m3/s): 1e-05
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 2.52574
# 	Annual O&M ($MM/yr): 0.66631
# 	Annual Fixed O&M ($MM/yr): 0.03351
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.6328
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.02199
# 	Flow In (m3/s): 1.19771
# 	Flow Out (m3/s): 1.19759
# 	Flow Waste (m3/s): 0.00012
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
#
# ==========================END WT3 MODEL RUN===========================
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
#
# KBHDP: DWI
# =========================SYSTEM LEVEL RESULTS=========================
# LCOW ($/m3): 1.62602
# Total Capital Investment ($MM): 12.06
# Total Annual Operating Costs ($MM/yr): 0.265
# Annual Fixed Operating Cost ($MM/yr): 0.159
# Annual Catalysts and Chemicals Cost ($MM/yr): 0.045
# Annual Electricity Costs ($MM/yr): 0.051
# Annual Other Variable Costs ($MM/yr): 0.01
# Treated water (m3/s): 0.02
# Total water recovery (%): 92.696
# Electricity intensity (kWh/m3): 1.263
# Electricity portion of LCOW (%): 4.863
# ======================================================================
#
# =========================UNIT PROCESS RESULTS=========================
#
#
# Well Field:
# 	Total Capital Investment ($MM): 0.2874
# 	Annual O&M ($MM/yr): 0.01306
# 	Annual Fixed O&M ($MM/yr): 0.00381
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00925
# 	Electricity Intensity (kWh/m3): 0.21197
# 	Unit LCOW ($/m3): 0.04919
# 	Flow In (m3/s): 0.02208
# 	Flow Out (m3/s): 0.02208
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Media Filtration:
# 	Total Capital Investment ($MM): 1.05471
# 	Annual O&M ($MM/yr): 0.01405
# 	Annual Fixed O&M ($MM/yr): 0.01404
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.00015
# 	Unit LCOW ($/m3): 0.12805
# 	Flow In (m3/s): 0.0134
# 	Flow Out (m3/s): 0.0134
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Cartridge Filtration:
# 	Total Capital Investment ($MM): 0.41352
# 	Annual O&M ($MM/yr): 0.00551
# 	Annual Fixed O&M ($MM/yr): 0.00551
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 1e-05
# 	Electricity Intensity (kWh/m3): 0.0002
# 	Unit LCOW ($/m3): 0.05021
# 	Flow In (m3/s): 0.0134
# 	Flow Out (m3/s): 0.0134
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Anti Scalant Addition:
# 	Total Capital Investment ($MM): 0.00984
# 	Annual O&M ($MM/yr): 0.01084
# 	Annual Fixed O&M ($MM/yr): 0.00013
# 	Annual Chemical Cost ($MM/yr): 0.01071
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.01778
# 	Flow In (m3/s): 0.0134
# 	Flow Out (m3/s): 0.0134
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# RO First Stage:
# 	Total Capital Investment ($MM): 0.48938
# 	Annual O&M ($MM/yr): 0.04751
# 	Annual Fixed O&M ($MM/yr): 0.00652
# 	Annual Chemical Cost ($MM/yr): 0.00465
# 	Annual Electricity Cost ($MM/yr): 0.02636
# 	Electricity Intensity (kWh/m3): 0.99586
# 	Unit LCOW ($/m3): 0.12291
# 	Flow In (m3/s): 0.0134
# 	Flow Out (m3/s): 0.01179
# 	Flow Waste (m3/s): 0.00164
#
# 	.....RO First Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 29.68 bar = 430 psi
# 	Area = 1330 m2 ---> 36 membrane modules
# 	Flux = 31.9 LMH
# 	TDS in = 1750.63 mg/L
# 	TDS out = 31.222 mg/L
# 	TDS waste = 14059.203 mg/L
# 	Flow in = 0.0134 m3/s = 0.30581 MGD = 212.37 gpm
# 	Flow out = 0.01179 m3/s = 0.26909 MGD = 186.87 gpm
# 	Flow waste = 0.00164 m3/s = 0.03748 MGD = 26.03 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 88.0%
#
# Passthrough:
# 	Total Capital Investment ($MM): 0.0
# 	Annual O&M ($MM/yr): 0.0
# 	Annual Fixed O&M ($MM/yr): 0.0
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0
# 	Flow In (m3/s): 0.00164
# 	Flow Out (m3/s): 0.00164
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Lime Softening:
# 	Total Capital Investment ($MM): 0.27112
# 	Annual O&M ($MM/yr): 0.02692
# 	Annual Fixed O&M ($MM/yr): 0.0036
# 	Annual Chemical Cost ($MM/yr): 0.02332
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.00025
# 	Unit LCOW ($/m3): 0.06902
# 	Flow In (m3/s): 0.00164
# 	Flow Out (m3/s): 0.00164
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.9
#
# RO Second Stage:
# 	Total Capital Investment ($MM): 0.05429
# 	Annual O&M ($MM/yr): 0.003
# 	Annual Fixed O&M ($MM/yr): 0.00072
# 	Annual Chemical Cost ($MM/yr): 0.00052
# 	Annual Electricity Cost ($MM/yr): 0.00168
# 	Electricity Intensity (kWh/m3): 0.5187
# 	Unit LCOW ($/m3): 0.01011
# 	Flow In (m3/s): 0.00164
# 	Flow Out (m3/s): 1e-05
# 	Flow Waste (m3/s): 0.00163
#
# 	.....RO Second Stage OPERATIONAL PARAMETERS.....
# 	Pressure = 15.94 bar = 231 psi
# 	Area = 10 m2 ---> 0 membrane modules
# 	Flux = 3.6 LMH
# 	TDS in = 14074.402 mg/L
# 	TDS out = 491.541 mg/L
# 	TDS waste = 14157.903 mg/L
# 	Flow in = 0.00164 m3/s = 0.03744 MGD = 26.0 gpm
# 	Flow out = 1e-05 m3/s = 0.00023 MGD = 0.16 gpm
# 	Flow waste = 0.00163 m3/s = 0.03721 MGD = 25.84 gpm
# 	Water Permeability = 4.2 m/(bar.hr)
# 	Salt Permeability = 0.35 m/hr
# 	RO Recovery = 0.6%
#
# Caustic Soda Addition:
# 	Total Capital Investment ($MM): 0.11623
# 	Annual O&M ($MM/yr): 0.00464
# 	Annual Fixed O&M ($MM/yr): 0.00155
# 	Annual Chemical Cost ($MM/yr): 0.00309
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.0189
# 	Flow In (m3/s): 0.02048
# 	Flow Out (m3/s): 0.02047
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Chlorination:
# 	Total Capital Investment ($MM): 2.21405
# 	Annual O&M ($MM/yr): 0.03177
# 	Annual Fixed O&M ($MM/yr): 0.02948
# 	Annual Chemical Cost ($MM/yr): 0.00229
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 5e-05
# 	Unit LCOW ($/m3): 0.27234
# 	Flow In (m3/s): 0.02047
# 	Flow Out (m3/s): 0.02047
# 	Flow Waste (m3/s): 0.0
# 	Chlorine dose (mg/L): 9.5
# 	Water Recovery (%): 99.99
#
# Treated Storage:
# 	Total Capital Investment ($MM): 0.76126
# 	Annual O&M ($MM/yr): 0.01001
# 	Annual Fixed O&M ($MM/yr): 0.01001
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.0
# 	Electricity Intensity (kWh/m3): 0.0
# 	Unit LCOW ($/m3): 0.09222
# 	Flow In (m3/s): 0.02047
# 	Flow Out (m3/s): 0.02047
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Deep Well Injection:
# 	Total Capital Investment ($MM): 6.31334
# 	Annual O&M ($MM/yr): 0.0844
# 	Annual Fixed O&M ($MM/yr): 0.08308
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.00132
# 	Electricity Intensity (kWh/m3): 0.40959
# 	Unit LCOW ($/m3): 0.76699
# 	Flow In (m3/s): 0.00163
# 	Flow Out (m3/s): 0.00163
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# Municipal Drinking:
# 	Total Capital Investment ($MM): 0.07456
# 	Annual O&M ($MM/yr): 0.01341
# 	Annual Fixed O&M ($MM/yr): 0.00099
# 	Annual Chemical Cost ($MM/yr): 0
# 	Annual Electricity Cost ($MM/yr): 0.01242
# 	Electricity Intensity (kWh/m3): 0.3072
# 	Unit LCOW ($/m3): 0.02829
# 	Flow In (m3/s): 0.02047
# 	Flow Out (m3/s): 0.02047
# 	Flow Waste (m3/s): 0.0
# 	Water Recovery (%): 99.99
#
# ======================================================================
#
# -----------------------------
# SITE NAME: USGS-472216102444601
# 0.9935866983372922
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-473108100561601
# 0.9938242280285036
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-473452111183001
# 0.994061757719715
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-473608103024301
# 0.9942992874109263
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-474556118431101
# 0.9945368171021378
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-474720099532801
# 0.9947743467933492
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-474720099532802
# 0.9950118764845606
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-474901119380801
# 0.995249406175772
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-475601118561801
# 0.9954869358669833
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-480534099012303
# 0.9957244655581948
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-480804104534601
# 0.9959619952494062
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-481231122481601
# 0.9961995249406176
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-481443122252801
# 0.996437054631829
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483306104114901
# 0.9966745843230403
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483345119330901
# 0.9969121140142517
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483435104104701
# 0.9971496437054632
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483518104101501
# 0.9973871733966746
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-483543104081901
# 0.997624703087886
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484127104061701
# 0.9978622327790974
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484135104055601
# 0.9980997624703087
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484150104053901
# 0.9983372921615202
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484151104042501
# 0.9985748218527316
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484205104052201
# 0.998812351543943
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484214104050001
# 0.9990498812351544
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-484217104042501
# 0.9992874109263657
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-485055122360402
# 0.9995249406175772
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: UT_GEOTH-SL-052
# 0.9997624703087886
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: UT_GEOTH-TO-028
# 1.0
# .................................
#
# Degrees of Freedom: 3
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................

# %% [markdown]
# Old Big Spring Run

# %%
case_study = 'big_spring'
scenario = 'dwi_a'
desired_recovery = 1
ro_bounds = 'other' # or 'seawater'

m = watertap_setup(case_study=case_study, scenario=scenario)
m = get_case_study(m=m)

# run the baseline watertap3 version of this treatment train
m = run_watertap3(m, desired_recovery=desired_recovery, ro_bounds=ro_bounds)

m.fs.reverse_osmosis.membrane_area.unfix()
m.fs.reverse_osmosis.feed.pressure.unfix()

m = run_and_return_model(m, objective=True,print_it=True)

print(m.fs.costing.LCOW())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 desired_recovery = 1
#       4 ro_bounds = 'other' # or 'seawater'
# ----> 6 m = watertap_setup(case_study=case_study, scenario=scenario)
#       7 m = get_case_study(m=m)
#       9 # run the baseline watertap3 version of this treatment train
#
# NameError: name 'watertap_setup' is not defined

# %%
# Read in brackish database. It is filtered for the correct columns. 
df = pd.read_csv('/Users/mhardika/Documents/AMO/GeoToolAll_Methods/Water Source Data/Brackish/USGS_brackish_filtered.csv', index_col='unique_site_ID')

# convert USGS unit to our units: gpm to m3s, 
df.well_yield = df.well_yield * 6.30902e-5 #gpm to m3s
df.TDS_mgL = df.TDS_mgL / 1000 #mgL to kg/m3
df = df.rename(columns={'TDS_mgL': 'TDS_kgm3'})

path = 'C:/Users/mhardika/Documents/watertap3/WaterTAP3/watertap3/watertap3/data'

# add state look up for elec prices and add elec price column
state_abbv_df = pd.read_csv(path + '/state_abbv.csv', index_col='abbv')
elec_price_df = pd.read_csv(path + '/industrial_electricity_costs_2023.csv', index_col='location')
df['state'] = df.state_alpha.map(state_abbv_df.us_state)
df['elec_price'] = df.state.map(elec_price_df.cost)

# filter for well of interest in the US
df = df[df.well_yield >= 0.01] #---> to be updated
df = df[df.TDS_kgm3 >= 0.5]
df = df[df.Latitude >= 22]
df = df[df.Longitude >= -150]
df = df[df.TDS_kgm3 <= 25]

# loop through brackish sites and calculate+save LCOW, capital, O&M, energy intensity, and recovery in a df.
capital = []
recovery = []
onm = []
lcow = []
pipe_cost = []
elec_int = []
tds_out = []
flow_in_list = []
tds_in_list = []
well_field_annual_op_main_cost_list = []
well_field_total_cap_inv_list = []
well_field_lcow_list = []
i = 0

for site in df.index:
    print('-----------------------------')
    print('SITE NAME:', site)
    i = i + 1
    print(i/len(df.index))
           
    m.fs.big_spring_feed.flow_vol_in.fix(df.loc[site].well_yield)
    m.fs.big_spring_feed.conc_mass_in[0, 'tds'].fix(df.loc[site].TDS_kgm3)
    m.fs.well_field.lift_height.fix(df.loc[site].well_depth_ft)
    
    m.fs.costing_param.electricity_price = df.loc[site].elec_price

    m = run_and_return_model(m, objective=True)

    # Basis is recalculated to be on treated volume basis instead of brine volume
    temp = pipe_costing(m.fs.deep_well_injection.flow_vol_in[0].value*3600*24,16.0934,pumping_velocity = 1.5)*(1-m.fs.costing.system_recovery())/m.fs.costing.system_recovery()
    
    flow_in_list.append(df.loc[site].well_yield)
    capital.append(m.fs.costing.capital_investment_total())
    recovery.append(m.fs.costing.system_recovery()*100)
    onm.append(m.fs.costing.operating_cost_annual())
    pipe_cost.append(temp)
    lcow.append(m.fs.costing.LCOW())
    elec_int.append(m.fs.costing.electricity_intensity())
    tds_out.append(m.fs.municipal_drinking.conc_mass_in[0, 'tds']())
    tds_in_list.append(df.loc[site].TDS_kgm3)
    well_field_annual_op_main_cost_list.append(m.fs.well_field.costing.annual_op_main_cost())
    well_field_total_cap_inv_list.append(m.fs.well_field.costing.total_cap_investment())
    well_field_lcow_list.append(m.fs.well_field.LCOW())
    
df['treatment_lcow'] = lcow
df['pipe_lcow'] = pipe_cost
df['lcow'] = df['treatment_lcow'] + df['pipe_lcow'] # Total LCOW which includes treatment and brine disposal costs
df['recovery'] = recovery
df['capital'] = capital
df['onm'] = onm
df['elec_int'] = elec_int
df['tds_out'] = tds_out
df['well_field_o&m'] = well_field_annual_op_main_cost_list
df['well_field_cap_inv'] = well_field_total_cap_inv_list
df['well_field_lcow'] = well_field_lcow_list
# Out:
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0183
# 0.0001953506544246923
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0274
# 0.0003907013088493846
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0297
# 0.000586051963274077
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0327
# 0.0007814026176987692
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0338
# 0.0009767532721234617
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0373
# 0.001172103926548154
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0411
# 0.0013674545809728462
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0412
# 0.0015628052353975385
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ0425
# 0.0017581558898222308
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: AZ_GEOTH-AZ
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395140084161700
# 0.7450673959757765
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395223091234901
# 0.7452627466302012
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395228109163401
# 0.7454580972846259
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395250088510601
# 0.7456534479390506
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395304111590701
# 0.7458487985934753
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395315104553801
# 0.7460441492479
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395322075075701
# 0.7462394999023246
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395339111581800
# 0.7464348505567494
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395340111590001
# 0.7466302012111741
# .................................
#
# Degrees of Freedom: 2
#
# Initial solve attempt OPTIMAL
#
# WaterTAP3 solution OPTIMAL
#
# .................................
# -----------------------------
# SITE NAME: USGS-395341112484301
# 0.7468255518655987
# .................................
#
# Degrees of Freedom: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 51
#      47 m.fs.well_field.lift_height.fix(df.loc[site].well_depth_ft)
#      49 m.fs.costing_param.electricity_price = df.loc[site].elec_price
# ---> 51 m = run_and_return_model(m, objective=True)
#      53 # Basis is recalculated to be on treated volume basis instead of brine volume
#      54 temp = pipe_costing(m.fs.deep_well_injection.flow_vol_in[0].value*3600*24,16.0934,pumping_velocity = 1.5)*(1-m.fs.costing.system_recovery())/m.fs.costing.system_recovery()
#
# File c:\users\mhardika\documents\watertap3\watertap3\watertap3\watertap3\utils\watertap.py:161, in run_and_return_model(m, solver, tolerance, tee, objective, max_attempts, print_it, initial_run, mip_solver)
#     159     m.fs.results = results = model_solver.solve(m, tee=tee, mip_solver=mip_solver)
#     160 else:
# --> 161     m.fs.results = results = model_solver.solve(m, tee=tee)
#     163 print(f'\nInitial solve attempt {results.solver.termination_condition.swapcase()}')
#     165 attempt_number = 1
#
# File c:\Users\mhardika\miniconda3\envs\watertap3\lib\site-packages\pyomo\opt\base\solvers.py:529, in OptSolver.solve(self, *args, **kwds)
#     527 if isinstance(arg, (_BlockData, IBlock)):
#     528     if isinstance(arg, _BlockData):
# --> 529         if not arg.is_constructed():
#     530             raise RuntimeError(
#     531                 "Attempting to solve model=%s with unconstructed "
#     532                 "component(s)" % (arg.name,) )
#     534     _model = arg
#
# File c:\Users\mhardika\miniconda3\envs\watertap3\lib\site-packages\pyomo\core\base\block.py:1650, in _BlockData.is_constructed(self)
#    1648     return False
#    1649 for x in self._decl_order:
# -> 1650     if x[0] is not None and x[0].active and not x[0].is_constructed():
#    1651         return False
#    1652 return True
#
# File c:\Users\mhardika\miniconda3\envs\watertap3\lib\site-packages\pyomo\core\base\block.py:1650, in _BlockData.is_constructed(self)
#    1648     return False
#    1649 for x in self._decl_order:
# -> 1650     if x[0] is not None and x[0].active and not x[0].is_constructed():
#    1651         return False
#    1652 return True
#
# File c:\Users\mhardika\miniconda3\envs\watertap3\lib\site-packages\pyomo\core\base\block.py:1650, in _BlockData.is_constructed(self)
#    1648     return False
#    1649 for x in self._decl_order:
# -> 1650     if x[0] is not None and x[0].active and not x[0].is_constructed():
#    1651         return False
#    1652 return True
#
# KeyboardInterrupt:

# %%
# df.to_csv('/Users/mhardika/Documents/AMO/GeoToolAll_Methods/Water Source Data/Brackish/brackish_sites_with_metrics_baseline_dwi_updated_costs_transport_updated_basis.csv') 
# df.to_csv('/Users/mhardika/Documents/AMO/GeoToolAll_Methods/Water Source Data/Brackish/brackish_sites_baseline_dwi_5Feb23.csv')
# df.to_csv('/Users/mhardika/Documents/AMO/GeoToolAll_Methods/Water Source Data/Brackish/brackish_sites_baseline_dwi_4Jun23.csv')
